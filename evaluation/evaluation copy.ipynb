# %% [markdown]
# # Evaluation Code for KSQL and ML
# Before evaluating, please run KSQL infrastructure with `test.pcap` generated from `../datasets/preparation2.py`, then run `../rule-detection/evaluation/consumer/script.py` to consume the results from Kafka, and lastly run `../rule-detection/evaluation/ksql_evaluation_dos.py` and `../rule-detection/evaluation/ksql_evaluation_ps.py` to find list of packets in the pcap (in the form of index) that is malicious/detected.
#
# **Metrics**
# - Accuracy, Precision, Recall, F1-Score
# - Inference Time for ML

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
import joblib
import time

# %%
DOS_MODEL_LOCATION = "../ai-detection/notebooks/models/postfs"
PS_MODEL_LOCATION = "../ai-detection/notebooks/modelsps/postfs"

# %% [markdown]
# ## Post-Processing for KSQL Predictions

# %%
# Get PCAP Indexes of all flows
# For example, if 125th, 126th, and 127th is part of k-th flow (in whole dataset train & test), then flow_packets[k] = [125, 126, 127]
flow_packets = []
with open("../datasets/output-old/pcap_indexes_run_index.txt") as file:
    for line in file:
        indexes = line.strip().split(",")
        if len(indexes[-1]) == 0:
            indexes = indexes[:-1]
        indexes = [int(x) for x in indexes]
        flow_packets.append(indexes)

# %%
# Creating mapping to convert whole dataset PCAP indexes to test dataset PCAP indexes
full_to_test_mapping = {}
with open("../datasets/output-old/test_pcap_index_mapping.txt") as file:
    for line in file:
        before, after = line.strip().split(",")
        before = int(before)
        after = int(after)
        assert before not in full_to_test_mapping
        full_to_test_mapping[before] = after

# %%
# Convert using mapping
test_flow_packets = []
for cur_packets in flow_packets:
    new_packets = []
    is_in_test = True

    debug_partial = False
    for idx in cur_packets:
        if idx not in full_to_test_mapping:
            is_in_test = False
            assert not debug_partial # if assertion error, there may be problem in your dataset preparation
            break
        debug_partial = True
        new_packets.append(full_to_test_mapping[idx])
    if is_in_test:
        test_flow_packets.append(new_packets)
    else:
        test_flow_packets.append(None)

# %%
test_flow_packets_set = [set(i) if i is not None else None for i in test_flow_packets]

# %%
np_test_flow_packets_set = pd.Series(np.array(test_flow_packets_set))
flow_packets_set_test_only = np_test_flow_packets_set[~np_test_flow_packets_set.isna()]

# %%
with open("../rule-detection/evaluation/detected_ksql_2_slowloris.txt") as file:
    detected_dos_idxs = [int(x.strip()) for x in file.readlines()]
detected_dos_idx_set = set(detected_dos_idxs)

with open("../rule-detection/evaluation/detected_ksql_2_portscan.txt") as file:
    detected_portscan_idxs = [int(x.strip()) for x in file.readlines()]
detected_portscan_idx_set = set(detected_portscan_idxs)

# %%
is_detected_dos = np.array([len(detected_dos_idx_set.intersection(flow_packet_set)) > 0 for flow_packet_set in flow_packets_set_test_only.values])
is_detected_dos = pd.Series(is_detected_dos)

is_detected_portscan = np.array([len(detected_portscan_idx_set.intersection(flow_packet_set)) > 0 for flow_packet_set in flow_packets_set_test_only.values])
is_detected_portscan = pd.Series(is_detected_portscan)

# %%
is_detected_dos.index = flow_packets_set_test_only.index
is_detected_portscan.index = flow_packets_set_test_only.index

# %%
# Load Test Dataset
flink_test = pd.read_csv('../datasets/output/test_final.csv', index_col=0)

# %%
assert set(flink_test['Old Index'].values).issubset(set(is_detected_dos.index))
assert set(flink_test['Old Index'].values).issubset(set(is_detected_portscan.index))

# %%
is_detected_dos_df = pd.DataFrame(is_detected_dos, columns=['Binary Prediction']).reset_index().rename(columns={'index': 'Old Index'})
is_detected_dos_df['Binary Prediction'] = np.where(is_detected_dos_df['Binary Prediction'], 'Slowloris', 'Not Slowloris')

is_detected_ps_df = pd.DataFrame(is_detected_portscan, columns=['Binary Prediction']).reset_index().rename(columns={'index': 'Old Index'})
is_detected_ps_df['Binary Prediction'] = np.where(is_detected_ps_df['Binary Prediction'], 'Portscan', 'Not Portscan')

# %%
flink_test_binary_dos = flink_test.merge(is_detected_dos_df, on=['Old Index'], how='left', indicator=True)
flink_test_binary_ps = flink_test.merge(is_detected_ps_df, on=['Old Index'], how='left', indicator=True)

# %%
flink_test_binary_dos["_merge"].value_counts()
# Out:
# _merge
# both          153696
# left_only          0
# right_only         0
# Name: count, dtype: int64

# %%
flink_test_binary_ps["_merge"].value_counts()
# Out:
# _merge
# both          153696
# left_only          0
# right_only         0
# Name: count, dtype: int64

# %%
flink_test_binary_dos['Binary Label'] = np.where(flink_test_binary_dos['Label'] == 'Slowloris', 'Slowloris', 'Not Slowloris')
flink_test_binary_ps['Binary Label'] = np.where(flink_test_binary_ps['Label'] == 'Portscan', 'Portscan', 'Not Portscan')

# %%
y_true_dos = flink_test_binary_dos['Binary Label']
y_pred_ksql_dos = flink_test_binary_dos['Binary Prediction']

y_true_ps = flink_test_binary_ps['Binary Label']
y_pred_ksql_ps = flink_test_binary_ps['Binary Prediction']

# %% [markdown]
# # Model Preparation

# %%
dt = joblib.load(f"{DOS_MODEL_LOCATION}/dt_tuned.pkl")
rf = joblib.load(f"{DOS_MODEL_LOCATION}/rf_tuned.pkl")
et = joblib.load(f"{DOS_MODEL_LOCATION}/et_tuned.pkl")
xg = joblib.load(f"{DOS_MODEL_LOCATION}/xg_tuned.pkl")
lgbm = joblib.load(f"{DOS_MODEL_LOCATION}/lgbm_tuned.pkl")
cat = joblib.load(f"{DOS_MODEL_LOCATION}/cat_tuned.pkl")
stk1 = joblib.load(f"{DOS_MODEL_LOCATION}/stk1_tuned.pkl")
stk2 = joblib.load(f"{DOS_MODEL_LOCATION}/stk2_tuned.pkl")
stk3 = joblib.load(f"{DOS_MODEL_LOCATION}/stk3_tuned.pkl")

# %%
fs = ['Fwd IAT Min', 'Bwd IAT Mean', 'Fwd Seg Size Min', 'Flow Packets/s', 'Fwd Packets/s', 'Total Length of Bwd Packet', 'Bwd Act Data Pkts', 'Bwd IAT Min', 'Flow IAT Mean', 'FIN Flag Count', 'Bwd Init Win Bytes', 'Fwd Bulk Rate Avg', 'Active Min', 'Fwd Packet Length Max', 'Fwd Packet Length Min', 'Bwd Packets/s', 'Bwd Header Length', 'Bwd Packet Length Mean', 'Subflow Bwd Bytes', 'Flow Duration', 'Flow IAT Min', 'Total Bwd packets', 'Fwd Segment Size Avg', 'FWD Init Win Bytes', 'Packet Length Mean', 'Down/Up Ratio', 'ACK Flag Count', 'Fwd IAT Total', 'SYN Flag Count', 'Bwd Packet Length Max', 'Subflow Fwd Packets', 'Fwd Bytes/Bulk Avg', 'Flow IAT Max', 'Fwd IAT Mean', 'Fwd IAT Std', 'Fwd Header Length']

# %%
top_3_models = ['rf', 'xg', 'lgbm']

# %%
labelencoder = LabelEncoder()
labelencoder.fit_transform(['Not Slowloris', 'Slowloris'])
# Out:
# array([0, 1])

# %%
X_test_fs = flink_test[fs]
y_test = labelencoder.transform(flink_test_binary_dos['Binary Label'])

# %% [markdown]
# ## Accuracy, Precision, Recall, F1-Score

# %% [markdown]
# ### DoS

# %% [markdown]
# #### KSQL

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report,confusion_matrix,precision_recall_fscore_support, accuracy_score

# Evaluation metrics
precision, recall, fscore, none = precision_recall_fscore_support(y_true_dos, y_pred_ksql_dos, average='macro')

# Print results
print('Accuracy of KSQL: ' + str(accuracy_score(y_true_dos, y_pred_ksql_dos)))
print('Precision of KSQL: ' + str(precision))
print('Recall of KSQL: ' + str(recall))
print('F1-score of KSQL: ' + str(fscore))
print(classification_report(y_true_dos, y_pred_ksql_dos, digits=5))

# Confusion matrix visualization
cm = confusion_matrix(y_true_dos, y_pred_ksql_dos)
f, ax = plt.subplots(figsize=(5, 5))
sns.heatmap(cm, annot=True, linewidth=0.5, linecolor="red", fmt=".0f", ax=ax)
plt.xlabel("y_pred")
plt.ylabel("y_true")
plt.show()
# Out:
# Accuracy of KSQL: 0.7858369768894441
# Precision of KSQL: 0.4953329286897751
# Recall of KSQL: 0.3958494474232751
# F1-score of KSQL: 0.4400384733091418
#                precision    recall  f1-score   support
#
# Not Slowloris    0.99067   0.79170   0.88008    152558
#     Slowloris    0.00000   0.00000   0.00000      1138
#
#      accuracy                        0.78584    153696
#     macro avg    0.49533   0.39585   0.44004    153696
#  weighted avg    0.98333   0.78584   0.87356    153696

# %%
flink_test_binary_dos[(flink_test_binary_dos['Label'] == 'Portscan') & (flink_test_binary_dos['Binary Prediction'] == 'Slowloris')]
# Out:
#             Src IP  Src Port         Dst IP  Dst Port  Protocol  \
# 63614   172.16.0.1     54176  192.168.10.50      3372         6
# 63615   172.16.0.1     46948  192.168.10.50      7004         6
# 63616   172.16.0.1     42260  192.168.10.50      2144         6
# 63617   172.16.0.1     52120  192.168.10.50      1862         6
# 63618   172.16.0.1     59188  192.168.10.50      1078         6
# ...            ...       ...            ...       ...       ...
# 115507  172.16.0.1     47339  192.168.10.50     10001         6
# 115508  172.16.0.1     47339  192.168.10.50      5987         6
# 115509  172.16.0.1     47339  192.168.10.50      2135         6
# 115513  172.16.0.1     44870  192.168.10.50      2000         6
# 115514  172.16.0.1     47606  192.168.10.50      5060         6
#
#                          Timestamp  Flow Duration  Total Fwd Packet  \
# 63614   2017-07-07 17:55:45.857960           73.0                 1
# 63615   2017-07-07 17:55:45.857984           65.0                 1
# 63616   2017-07-07 17:55:45.858008           52.0                 1
# 63617   2017-07-07 17:55:45.858047           43.0                 1
# 63618   2017-07-07 17:55:45.858090           48.0                 1
# ...                            ...            ...               ...
# 115507  2017-07-07 18:23:52.026658           45.0                 1
# 115508  2017-07-07 18:23:52.026752           37.0                 1
# 115509  2017-07-07 18:23:52.026762           35.0                 1
# 115513  2017-07-07 18:23:53.255404           57.0                 1
# 115514  2017-07-07 18:23:53.256235           74.0                 1
#
#         Total Bwd packets  Total Length of Fwd Packet  ...  ICMP Type  \
# 63614                   1                         0.0  ...          0
# 63615                   1                         0.0  ...          0
# 63616                   1                         0.0  ...          0
# 63617                   1                         0.0  ...          0
# 63618                   1                         0.0  ...          0
# ...                   ...                         ...  ...        ...
# 115507                  1                         0.0  ...          0
# 115508                  1                         0.0  ...          0
# 115509                  1                         0.0  ...          0
# 115513                  1                         0.0  ...          0
# 115514                  1                         0.0  ...          0
#
#         Fwd TCP Retrans. Count  Bwd TCP Retrans. Count  \
# 63614                        0                       0
# 63615                        0                       0
# 63616                        0                       0
# 63617                        0                       0
# 63618                        0                       0
# ...                        ...                     ...
# 115507                       0                       0
# 115508                       0                       0
# 115509                       0                       0
# 115513                       0                       0
# 115514                       0                       0
#
#         Total TCP Retrans. Count  Total Connection Flow Time     Label  \
# 63614                          0                          73  Portscan
# 63615                          0                          65  Portscan
# 63616                          0                          52  Portscan
# 63617                          0                          43  Portscan
# 63618                          0                          48  Portscan
# ...                          ...                         ...       ...
# 115507                         0                          45  Portscan
# 115508                         0                          37  Portscan
# 115509                         0                          35  Portscan
# 115513                         0                          57  Portscan
# 115514                         0                          74  Portscan
#
#         Old Index  Binary Prediction  _merge   Binary Label
# 63614      782541          Slowloris    both  Not Slowloris
# 63615      716537          Slowloris    both  Not Slowloris
# 63616      793478          Slowloris    both  Not Slowloris
# 63617      959673          Slowloris    both  Not Slowloris
# 63618      562621          Slowloris    both  Not Slowloris
# ...           ...                ...     ...            ...
# 115507     964756          Slowloris    both  Not Slowloris
# 115508     751138          Slowloris    both  Not Slowloris
# 115509     704995          Slowloris    both  Not Slowloris
# 115513    1038574          Slowloris    both  Not Slowloris
# 115514     597671          Slowloris    both  Not Slowloris
#
# [31498 rows x 97 columns]

# %% [markdown]
# #### Machine Learning

# %%
# Decision Tree
# calculate the prediction time per sample in milliseconds
start = time.time()
y_predict = dt.predict(X_test_fs)
end = time.time()

predict_time_dt = (end - start) / len(X_test_fs) * 1000
print('Prediction time per sample: ', predict_time_dt)
y_predict = np.where(pd.Series(labelencoder.inverse_transform(y_predict)) == 'Slowloris', 'Slowloris', 'Not Slowloris')

# Evaluation metrics
precision, recall, fscore, none = precision_recall_fscore_support(y_true_dos, y_predict, average='macro')

# Print results
print('Accuracy of DT: ' + str(accuracy_score(y_true_dos, y_predict)))
print('Precision of DT: ' + str(precision))
print('Recall of DT: ' + str(recall))
print('F1-score of DT: ' + str(fscore))
print(classification_report(y_true_dos, y_predict, digits=5))

# Confusion matrix visualization
cm = confusion_matrix(y_true_dos, y_predict)
f, ax = plt.subplots(figsize=(5, 5))
sns.heatmap(cm, annot=True, linewidth=0.5, linecolor="red", fmt=".0f", ax=ax)
plt.xlabel("y_pred")
plt.ylabel("y_true")
plt.show()
# Out:
# Prediction time per sample:  8.39373133665518e-05
# Accuracy of DT: 0.9981587028940245
# Precision of DT: 0.9973418191762222
# Recall of DT: 0.876967320573758
# F1-score of DT: 0.9287512698990616
#                precision    recall  f1-score   support
#
# Not Slowloris    0.99817   0.99998   0.99907    152558
#     Slowloris    0.99652   0.75395   0.85843      1138
#
#      accuracy                        0.99816    153696
#     macro avg    0.99734   0.87697   0.92875    153696
#  weighted avg    0.99816   0.99816   0.99803    153696

# %%
# Random Forest
# calculate the prediction time per sample in milliseconds
start = time.time()
y_predict = rf.predict(X_test_fs)
end = time.time()

predict_time_rf = (end - start) / len(X_test_fs) * 1000
print('Prediction time per sample: ', predict_time_rf)
y_predict = np.where(pd.Series(labelencoder.inverse_transform(y_predict)) == 'Slowloris', 'Slowloris', 'Not Slowloris')

# Evaluation metrics
precision, recall, fscore, none = precision_recall_fscore_support(y_true_dos, y_predict, average='macro')

# Print results
print('Accuracy of RF: ' + str(accuracy_score(y_true_dos, y_predict)))
print('Precision of RF: ' + str(precision))
print('Recall of RF: ' + str(recall))
print('F1-score of RF: ' + str(fscore))
print(classification_report(y_true_dos, y_predict, digits=5))

# Confusion matrix visualization
cm = confusion_matrix(y_true_dos, y_predict)
f, ax = plt.subplots(figsize=(5, 5))
sns.heatmap(cm, annot=True, linewidth=0.5, linecolor="red", fmt=".0f", ax=ax)
plt.xlabel("y_pred")
plt.ylabel("y_true")
plt.show()
# Out:
# Prediction time per sample:  0.0012571051446889654
# Accuracy of RF: 0.997924474286904
# Precision of RF: 0.9983509211887862
# Recall of RF: 0.8602779176370641
# F1-score of RF: 0.918058699173386
#                precision    recall  f1-score   support
#
# Not Slowloris    0.99792   0.99999   0.99896    152558
#     Slowloris    0.99878   0.72056   0.83716      1138
#
#      accuracy                        0.99792    153696
#     macro avg    0.99835   0.86028   0.91806    153696
#  weighted avg    0.99793   0.99792   0.99776    153696

# %%
# Extra Trees
# calculate the prediction time per sample in milliseconds
start = time.time()
y_predict = et.predict(X_test_fs)
end = time.time()

predict_time_et = (end - start) / len(X_test_fs) * 1000
print('Prediction time per sample: ', predict_time_et)
y_predict = np.where(pd.Series(labelencoder.inverse_transform(y_predict)) == 'Slowloris', 'Slowloris', 'Not Slowloris')

# Evaluation metrics
precision, recall, fscore, none = precision_recall_fscore_support(y_true_dos, y_predict, average='macro')

# Print results
print('Accuracy of ET: ' + str(accuracy_score(y_true_dos, y_predict)))
print('Precision of ET: ' + str(precision))
print('Recall of ET: ' + str(recall))
print('F1-score of ET: ' + str(fscore))
print(classification_report(y_true_dos, y_predict, digits=5))

# Confusion matrix visualization
cm = confusion_matrix(y_true_dos, y_predict)
f, ax = plt.subplots(figsize=(5, 5))
sns.heatmap(cm, annot=True, linewidth=0.5, linecolor="red", fmt=".0f", ax=ax)
plt.xlabel("y_pred")
plt.ylabel("y_true")
plt.show()
# Out:
# Prediction time per sample:  0.0007611660815367421
# Accuracy of ET: 0.9976577139287945
# Precision of ET: 0.9962913872901338
# Recall of ET: 0.8435721274902598
# F1-score of ET: 0.9058556466861101
#                precision    recall  f1-score   support
#
# Not Slowloris    0.99767   0.99997   0.99882    152558
#     Slowloris    0.99491   0.68717   0.81289      1138
#
#      accuracy                        0.99766    153696
#     macro avg    0.99629   0.84357   0.90586    153696
#  weighted avg    0.99765   0.99766   0.99744    153696

# %%
# XGBoost
# calculate the prediction time per sample in milliseconds
start = time.time()
y_predict = xg.predict(X_test_fs)
end = time.time()

predict_time_xg = (end - start) / len(X_test_fs) * 1000
print('Prediction time per sample: ', predict_time_xg)
y_predict = np.where(pd.Series(labelencoder.inverse_transform(y_predict)) == 'Slowloris', 'Slowloris', 'Not Slowloris')

# Evaluation metrics
precision, recall, fscore, none = precision_recall_fscore_support(y_true_dos, y_predict, average='macro')

# Print results
print('Accuracy of XG: ' + str(accuracy_score(y_true_dos, y_predict)))
print('Precision of XG: ' + str(precision))
print('Recall of XG: ' + str(recall))
print('F1-score of XG: ' + str(fscore))
print(classification_report(y_true_dos, y_predict, digits=5))

# Confusion matrix visualization
cm = confusion_matrix(y_true_dos, y_predict)
f, ax = plt.subplots(figsize=(5, 5))
sns.heatmap(cm, annot=True, linewidth=0.5, linecolor="red", fmt=".0f", ax=ax)
plt.xlabel("y_pred")
plt.ylabel("y_true")
plt.show()
# Out:
# Prediction time per sample:  0.00019965477345165004
# Accuracy of XG: 0.9978268790339371
# Precision of XG: 0.997065642228705
# Recall of XG: 0.8545595877090832
# F1-score of XG: 0.9137243021617274
#                precision    recall  f1-score   support
#
# Not Slowloris    0.99783   0.99998   0.99891    152558
#     Slowloris    0.99630   0.70914   0.82854      1138
#
#      accuracy                        0.99783    153696
#     macro avg    0.99707   0.85456   0.91372    153696
#  weighted avg    0.99782   0.99783   0.99765    153696

# %%
# LightGBM
# calculate the prediction time per sample in milliseconds
start = time.time()
y_predict = lgbm.predict(X_test_fs)
end = time.time()

predict_time_lgbm = (end - start) / len(X_test_fs) * 1000
print('Prediction time per sample: ', predict_time_lgbm)
y_predict = np.where(pd.Series(labelencoder.inverse_transform(y_predict)) == 'Slowloris', 'Slowloris', 'Not Slowloris')

# Evaluation metrics
precision, recall, fscore, none = precision_recall_fscore_support(y_true_dos, y_predict, average='macro')

# Print results
print('Accuracy of LGBM: ' + str(accuracy_score(y_true_dos, y_predict)))
print('Precision of LGBM: ' + str(precision))
print('Recall of LGBM: ' + str(recall))
print('F1-score of LGBM: ' + str(fscore))
print(classification_report(y_true_dos, y_predict, digits=5))

# Confusion matrix visualization
cm = confusion_matrix(y_true_dos, y_predict)
f, ax = plt.subplots(figsize=(5, 5))
sns.heatmap(cm, annot=True, linewidth=0.5, linecolor="red", fmt=".0f", ax=ax)
plt.xlabel("y_pred")
plt.ylabel("y_true")
plt.show()
# Out:
# Prediction time per sample:  0.0005332664254057688
# Accuracy of LGBM: 0.9981391838434311
# Precision of LGBM: 0.9984821845534751
# Recall of LGBM: 0.8747770389024419
# F1-score of LGBM: 0.927744613029722
#                precision    recall  f1-score   support
#
# Not Slowloris    0.99814   0.99999   0.99906    152558
#     Slowloris    0.99883   0.74956   0.85643      1138
#
#      accuracy                        0.99814    153696
#     macro avg    0.99848   0.87478   0.92774    153696
#  weighted avg    0.99814   0.99814   0.99801    153696

# %%
# CatBoost
# calculate the prediction time per sample in milliseconds
start = time.time()
y_predict = cat.predict(X_test_fs)
end = time.time()
print('Prediction time per sample: ', (end - start) / len(X_test_fs)*1000)
y_predict = np.where(pd.Series(labelencoder.inverse_transform(y_predict)) == 'Slowloris', 'Slowloris', 'Not Slowloris')

# Evaluation metrics
precision, recall, fscore, none = precision_recall_fscore_support(y_true_dos, y_predict, average='macro')

# Print results
print('Accuracy of Cat: ' + str(accuracy_score(y_true_dos, y_predict)))
print('Precision of Cat: ' + str(precision))
print('Recall of Cat: ' + str(recall))
print('F1-score of Cat: ' + str(fscore))
print(classification_report(y_true_dos, y_predict, digits=5))

# Confusion matrix visualization
cm = confusion_matrix(y_true_dos, y_predict)
f, ax = plt.subplots(figsize=(5, 5))
sns.heatmap(cm, annot=True, linewidth=0.5, linecolor="red", fmt=".0f", ax=ax)
plt.xlabel("y_pred")
plt.ylabel("y_true")
plt.show()
# Out:
# Prediction time per sample:  0.00015845087550963655
# Accuracy of Cat: 0.9976967520299813
# Precision of Cat: 0.9982095939286744
# Recall of Cat: 0.8449000617495421
# F1-score of Cat: 0.9074247192413416
#                precision    recall  f1-score   support
#
# Not Slowloris    0.99769   0.99999   0.99884    152558
#     Slowloris    0.99873   0.68981   0.81601      1138
#
#      accuracy                        0.99770    153696
#     macro avg    0.99821   0.84490   0.90742    153696
#  weighted avg    0.99770   0.99770   0.99749    153696

# %%
top_3_models
# Out:
# ['rf', 'xg', 'lgbm']

# %%
# Ensemble method 1: traditional stacking

# !!! WARNING: always update based used models below based on top_3_models in training !!!
start = time.time()
rf_test = rf.predict(X_test_fs)
xg_test = xg.predict(X_test_fs)
lgbm_test = lgbm.predict(X_test_fs)

rf_test = rf_test.reshape(-1, 1)
xg_test = xg_test.reshape(-1, 1)
lgbm_test = lgbm_test.reshape(-1, 1)

x_test = np.concatenate([rf_test, xg_test, lgbm_test], axis=1)

y_predict = stk1.predict(x_test)
end = time.time()
print('Prediction time per sample: ', (end - start) / len(X_test_fs)*1000)
y_predict = np.where(pd.Series(labelencoder.inverse_transform(y_predict)) == 'Slowloris', 'Slowloris', 'Not Slowloris')

# Evaluation metrics
precision, recall, fscore, none = precision_recall_fscore_support(y_true_dos, y_predict, average='macro')

# Print results
print('Accuracy of STK Traditional: ' + str(accuracy_score(y_true_dos, y_predict)))
print('Precision of STK Traditional: ' + str(precision))
print('Recall of STK Traditional: ' + str(recall))
print('F1-score of STK Traditional: ' + str(fscore))
print(classification_report(y_true_dos, y_predict, digits=5))

# Confusion matrix visualization
cm = confusion_matrix(y_true_dos, y_predict)
f, ax = plt.subplots(figsize=(5, 5))
sns.heatmap(cm, annot=True, linewidth=0.5, linecolor="red", fmt=".0f", ax=ax)
plt.xlabel("y_pred")
plt.ylabel("y_true")
plt.show()
# Out:
# Prediction time per sample:  0.0024075551428150536
# Accuracy of STK Traditional: 0.9978268790339371
# Precision of STK Traditional: 0.997065642228705
# Recall of STK Traditional: 0.8545595877090832
# F1-score of STK Traditional: 0.9137243021617274
#                precision    recall  f1-score   support
#
# Not Slowloris    0.99783   0.99998   0.99891    152558
#     Slowloris    0.99630   0.70914   0.82854      1138
#
#      accuracy                        0.99783    153696
#     macro avg    0.99707   0.85456   0.91372    153696
#  weighted avg    0.99782   0.99783   0.99765    153696

# %%
# Ensemble method 2: confidence-based stacking

# !!! WARNING: always update based used models below based on top_3_models in training !!!
start = time.time()
rf_prob_test = rf.predict_proba(X_test_fs)
xg_prob_test = xg.predict_proba(X_test_fs)
lgbm_prob_test = lgbm.predict_proba(X_test_fs)

x_test = np.concatenate([rf_prob_test, xg_prob_test, lgbm_prob_test], axis=1)

y_predict = stk2.predict(x_test)
end = time.time()
print('Prediction time per sample: ', (end - start) / len(X_test_fs)*1000)
y_predict = np.where(pd.Series(labelencoder.inverse_transform(y_predict)) == 'Slowloris', 'Slowloris', 'Not Slowloris')

# Evaluation metrics
precision, recall, fscore, none = precision_recall_fscore_support(y_true_dos, y_predict, average='macro')

# Print results
print('Accuracy of STK Confidence: ' + str(accuracy_score(y_true_dos, y_predict)))
print('Precision of STK Confidence: ' + str(precision))
print('Recall of STK Confidence: ' + str(recall))
print('F1-score of STK Confidence: ' + str(fscore))
print(classification_report(y_true_dos, y_predict, digits=5))

# Confusion matrix visualization
cm = confusion_matrix(y_true_dos, y_predict)
f, ax = plt.subplots(figsize=(5, 5))
sns.heatmap(cm, annot=True, linewidth=0.5, linecolor="red", fmt=".0f", ax=ax)
plt.xlabel("y_pred")
plt.ylabel("y_true")
plt.show()
# Out:
# Prediction time per sample:  0.0020956654313353733
# Accuracy of STK Confidence: 0.9978594107849261
# Precision of STK Confidence: 0.9989240419394716
# Recall of STK Confidence: 0.8554481546572935
# F1-score of STK Confidence: 0.914972484133067
#                precision    recall  f1-score   support
#
# Not Slowloris    0.99785   1.00000   0.99892    152558
#     Slowloris    1.00000   0.71090   0.83102      1138
#
#      accuracy                        0.99786    153696
#     macro avg    0.99892   0.85545   0.91497    153696
#  weighted avg    0.99786   0.99786   0.99768    153696

# %%
# Ensemble method 3: hybrid stacking

# !!! WARNING: always update based used models below based on top_3_models in training !!!
start = time.time()

rf_test = rf.predict(X_test_fs)
xg_test = xg.predict(X_test_fs)
lgbm_test = lgbm.predict(X_test_fs)

rf_prob_test = rf.predict_proba(X_test_fs)
xg_prob_test = xg.predict_proba(X_test_fs)
lgbm_prob_test = lgbm.predict_proba(X_test_fs)

rf_test = rf_test.reshape(-1, 1)
xg_test = xg_test.reshape(-1, 1)
lgbm_test = lgbm_test.reshape(-1, 1)

x_test = np.concatenate([rf_test, xg_test, lgbm_test] + [rf_prob_test, xg_prob_test, lgbm_prob_test], axis=1)

y_predict = stk3.predict(x_test)
end = time.time()
print('Prediction time per sample: ', (end - start) / len(X_test_fs)*1000)
y_predict = np.where(pd.Series(labelencoder.inverse_transform(y_predict)) == 'Slowloris', 'Slowloris', 'Not Slowloris')

# Evaluation metrics
precision, recall, fscore, none = precision_recall_fscore_support(y_true_dos, y_predict, average='macro')

# Print results
print('Accuracy of STK Hybrid: ' + str(accuracy_score(y_true_dos, y_predict)))
print('Precision of STK Hybrid: ' + str(precision))
print('Recall of STK Hybrid: ' + str(recall))
print('F1-score of STK Hybrid: ' + str(fscore))
print(classification_report(y_true_dos, y_predict, digits=5))

# Confusion matrix visualization
cm = confusion_matrix(y_true_dos, y_predict)
f, ax = plt.subplots(figsize=(5, 5))
sns.heatmap(cm, annot=True, linewidth=0.5, linecolor="red", fmt=".0f", ax=ax)
plt.xlabel("y_pred")
plt.ylabel("y_true")
plt.show()
# Out:
# Prediction time per sample:  0.00459421755695204
# Accuracy of STK Hybrid: 0.9978268790339371
# Precision of STK Hybrid: 0.997065642228705
# Recall of STK Hybrid: 0.8545595877090832
# F1-score of STK Hybrid: 0.9137243021617274
#                precision    recall  f1-score   support
#
# Not Slowloris    0.99783   0.99998   0.99891    152558
#     Slowloris    0.99630   0.70914   0.82854      1138
#
#      accuracy                        0.99783    153696
#     macro avg    0.99707   0.85456   0.91372    153696
#  weighted avg    0.99782   0.99783   0.99765    153696

# %% [markdown]
# ### Port Scan

# %%
dt = joblib.load(f"{PS_MODEL_LOCATION}/dt_tuned.pkl")
rf = joblib.load(f"{PS_MODEL_LOCATION}/rf_tuned.pkl")
et = joblib.load(f"{PS_MODEL_LOCATION}/et_tuned.pkl")
xg = joblib.load(f"{PS_MODEL_LOCATION}/xg_tuned.pkl")
lgbm = joblib.load(f"{PS_MODEL_LOCATION}/lgbm_tuned.pkl")
cat = joblib.load(f"{PS_MODEL_LOCATION}/cat_tuned.pkl")
stk1 = joblib.load(f"{PS_MODEL_LOCATION}/stk1_tuned.pkl")
stk2 = joblib.load(f"{PS_MODEL_LOCATION}/stk2_tuned.pkl")
stk3 = joblib.load(f"{PS_MODEL_LOCATION}/stk3_tuned.pkl")

# %%
fs = ['Bwd RST Flags', 'FWD Init Win Bytes', 'RST Flag Count', 'Flow Duration', 'Packet Length Max', 'Flow Packets/s', 'Protocol', 'Total Length of Fwd Packet', 'Flow IAT Max', 'Fwd Seg Size Min', 'Average Packet Size', 'Packet Length Mean', 'Fwd Packet Length Max', 'Bwd IAT Mean', 'Total Fwd Packet', 'Flow Bytes/s', 'Fwd Act Data Pkts', 'Bwd Packets/s', 'Bwd Packet Length Std', 'Fwd IAT Total', 'Flow IAT Mean', 'Flow IAT Min', 'Fwd Segment Size Avg', 'Fwd Header Length', 'Bwd Packet Length Mean', 'Packet Length Std', 'Fwd IAT Min', 'Packet Length Variance', 'Bwd IAT Max']

# %%
top_3_models = ['et', 'rf', 'lgbm']

# %%
labelencoder = LabelEncoder()
labelencoder.fit_transform(['Not Portscan', 'Portscan'])
# Out:
# array([0, 1])

# %%
X_test_fs = flink_test[fs]
y_test = labelencoder.transform(flink_test_binary_ps['Binary Label'])

# %% [markdown]
# #### KSQL

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report,confusion_matrix,precision_recall_fscore_support, accuracy_score

# Evaluation metrics
precision, recall, fscore, none = precision_recall_fscore_support(y_true_ps, y_pred_ksql_ps, average='weighted')

# Print results
print('Accuracy of KSQL: ' + str(accuracy_score(y_true_ps, y_pred_ksql_ps)))
print('Precision of KSQL: ' + str(precision))
print('Recall of KSQL: ' + str(recall))
print('F1-score of KSQL: ' + str(fscore))
print(classification_report(y_true_ps, y_pred_ksql_ps, digits=5))

# Confusion matrix visualization
cm = confusion_matrix(y_true_ps, y_pred_ksql_ps)
f, ax = plt.subplots(figsize=(5, 5))
sns.heatmap(cm, annot=True, linewidth=0.5, linecolor="red", fmt=".0f", ax=ax)
plt.xlabel("y_pred")
plt.ylabel("y_true")
plt.show()
# Out:
# Accuracy of KSQL: 0.9881389235894232
# Precision of KSQL: 0.9887785125172622
# Recall of KSQL: 0.9881389235894232
# F1-score of KSQL: 0.9882590722966741
#               precision    recall  f1-score   support
#
# Not Portscan    0.99998   0.98507   0.99247    121888
#     Portscan    0.94587   0.99991   0.97214     31808
#
#     accuracy                        0.98814    153696
#    macro avg    0.97292   0.99249   0.98230    153696
# weighted avg    0.98878   0.98814   0.98826    153696

# %%
flink_test_binary_ps[flink_test_binary_ps['Label'] == 'Portscan']['Src IP'].unique()
# Out:
# array(['172.16.0.1'], dtype=object)

# %%
len(flink_test_binary_ps[(flink_test_binary_ps['Label'] == 'Benign') & (flink_test_binary_ps['Binary Prediction'] == 'Portscan')]['Src Port'].unique())
# Out:
# 1786

# %%
len(flink_test_binary_ps[(flink_test_binary_ps['Label'] == 'Portscan') & (flink_test_binary_ps['Binary Prediction'] == 'Portscan')]['Src Port'].unique())
# Out:
# 8105

# %%
flink_test_binary_ps[(flink_test_binary_ps['Label'] == 'Portscan') & (flink_test_binary_ps['Binary Prediction'] == 'Portscan')]['Dst Port']
# Out:
# 63614     3372
# 63615     7004
# 63616     2144
# 63617     1862
# 63618     1078
#           ...
# 115515      21
# 115516      22
# 115608      80
# 115609     445
# 115617     139
# Name: Dst Port, Length: 31805, dtype: int64

# %%
predicted_as_ps = flink_test_binary_ps[(flink_test_binary_ps['Binary Prediction'] == 'Portscan')]

# %%
len((predicted_as_ps["Dst IP"] + predicted_as_ps["Dst Port"].astype(str)).unique())
# Out:
# 1071

# %%
ksqldb_failed = flink_test_binary_ps[(flink_test_binary_ps['Binary Prediction'] == 'Portscan') & (flink_test_binary_ps['Label'] == 'Benign')]

# %%
ksqldb_failed
# Out:
#                Src IP  Src Port         Dst IP  Dst Port  Protocol  \
# 66614   192.168.10.50     42506   192.168.10.3       389         6
# 66615   192.168.10.50     58198   192.168.10.3        88         6
# 74612    192.168.10.8      8352  192.168.10.50     61904         6
# 74613    192.168.10.8      8351  192.168.10.50        21         6
# 77015   192.168.10.50      6106     172.16.0.1     53126         6
# ...               ...       ...            ...       ...       ...
# 151075  192.168.10.14     62615   192.168.10.3        53        17
# 151076  192.168.10.14     63259   192.168.10.3        53        17
# 151077  192.168.10.14     53264   192.168.10.3        53        17
# 151078   192.168.10.3     62473   192.168.10.1        53        17
# 151079  192.168.10.14     60740   192.168.10.3        53        17
#
#                          Timestamp  Flow Duration  Total Fwd Packet  \
# 66614   2017-07-07 17:55:48.251761          579.0                12
# 66615   2017-07-07 17:55:48.270006         1276.0                10
# 74612   2017-07-07 17:55:58.667877        23925.0                17
# 74613   2017-07-07 17:55:58.539781       152430.0                22
# 77015   2017-07-07 17:55:45.864352            1.0                 1
# ...                            ...            ...               ...
# 151075  2017-07-07 19:13:59.632983          204.0                 2
# 151076  2017-07-07 19:13:59.919958          338.0                 2
# 151077  2017-07-07 19:13:59.920561          204.0                 2
# 151078  2017-07-07 19:13:59.921258        60053.0                 1
# 151079  2017-07-07 19:13:59.921103        60426.0                 4
#
#         Total Bwd packets  Total Length of Fwd Packet  ...  ICMP Type  \
# 66614                   7                       172.0  ...          0
# 66615                   9                      3174.0  ...          0
# 74612                  10                     20514.0  ...          0
# 74613                  27                       176.0  ...          0
# 77015                   1                         0.0  ...          0
# ...                   ...                         ...  ...        ...
# 151075                  2                        76.0  ...          0
# 151076                  2                        60.0  ...          0
# 151077                  2                        60.0  ...          0
# 151078                  1                        55.0  ...          0
# 151079                  2                       176.0  ...          0
#
#         Fwd TCP Retrans. Count  Bwd TCP Retrans. Count  \
# 66614                        6                       3
# 66615                        6                       4
# 74612                        4                       5
# 74613                       12                      13
# 77015                        0                       0
# ...                        ...                     ...
# 151075                       0                       0
# 151076                       0                       0
# 151077                       0                       0
# 151078                       0                       0
# 151079                       0                       0
#
#         Total TCP Retrans. Count  Total Connection Flow Time   Label  \
# 66614                          9                         579  Benign
# 66615                         10                        1276  Benign
# 74612                          9                       23925  Benign
# 74613                         25                      152430  Benign
# 77015                          0                           1  Benign
# ...                          ...                         ...     ...
# 151075                         0                         204  Benign
# 151076                         0                         338  Benign
# 151077                         0                         204  Benign
# 151078                         0                       60053  Benign
# 151079                         0                       60426  Benign
#
#         Old Index  Binary Prediction  _merge  Binary Label
# 66614      888568           Portscan    both  Not Portscan
# 66615      743697           Portscan    both  Not Portscan
# 74612      897704           Portscan    both  Not Portscan
# 74613      989479           Portscan    both  Not Portscan
# 77015      669203           Portscan    both  Not Portscan
# ...           ...                ...     ...           ...
# 151075    1009948           Portscan    both  Not Portscan
# 151076     642528           Portscan    both  Not Portscan
# 151077     542723           Portscan    both  Not Portscan
# 151078     462798           Portscan    both  Not Portscan
# 151079     660032           Portscan    both  Not Portscan
#
# [1820 rows x 97 columns]

# %% [markdown]
# #### Machine Learning

# %%
# Decision Tree
# calculate the prediction time per sample in milliseconds
start = time.time()
y_predict = dt.predict(X_test_fs)
end = time.time()

predict_time_dt = (end - start) / len(X_test_fs) * 1000
print('Prediction time per sample: ', predict_time_dt)
y_predict = np.where(pd.Series(labelencoder.inverse_transform(y_predict)) == 'Portscan', 'Portscan', 'Not Portscan')

# Evaluation metrics
precision, recall, fscore, none = precision_recall_fscore_support(y_true_ps, y_predict, average='macro')

# Print results
print('Accuracy of DT: ' + str(accuracy_score(y_true_ps, y_predict)))
print('Precision of DT: ' + str(precision))
print('Recall of DT: ' + str(recall))
print('F1-score of DT: ' + str(fscore))
print(classification_report(y_true_ps, y_predict, digits=5))

# Confusion matrix visualization
cm = confusion_matrix(y_true_ps, y_predict)
f, ax = plt.subplots(figsize=(5, 5))
sns.heatmap(cm, annot=True, linewidth=0.5, linecolor="red", fmt=".0f", ax=ax)
plt.xlabel("y_pred")
plt.ylabel("y_true")
plt.show()
# Out:
# Prediction time per sample:  6.531473996116548e-05
# Accuracy of DT: 0.9995835935873413
# Precision of DT: 0.9997376016793493
# Recall of DT: 0.9989939637826961
# F1-score of DT: 0.9993652417314904
#               precision    recall  f1-score   support
#
# Not Portscan    0.99948   1.00000   0.99974    121888
#     Portscan    1.00000   0.99799   0.99899     31808
#
#     accuracy                        0.99958    153696
#    macro avg    0.99974   0.99899   0.99937    153696
# weighted avg    0.99958   0.99958   0.99958    153696

# %%
# Random Forest
# calculate the prediction time per sample in milliseconds
start = time.time()
y_predict = rf.predict(X_test_fs)
end = time.time()

predict_time_rf = (end - start) / len(X_test_fs) * 1000
print('Prediction time per sample: ', predict_time_rf)
y_predict = np.where(pd.Series(labelencoder.inverse_transform(y_predict)) == 'Portscan', 'Portscan', 'Not Portscan')

# Evaluation metrics
precision, recall, fscore, none = precision_recall_fscore_support(y_true_ps, y_predict, average='macro')

# Print results
print('Accuracy of RF: ' + str(accuracy_score(y_true_ps, y_predict)))
print('Precision of RF: ' + str(precision))
print('Recall of RF: ' + str(recall))
print('F1-score of RF: ' + str(fscore))
print(classification_report(y_true_ps, y_predict, digits=5))

# Confusion matrix visualization
cm = confusion_matrix(y_true_ps, y_predict)
f, ax = plt.subplots(figsize=(5, 5))
sns.heatmap(cm, annot=True, linewidth=0.5, linecolor="red", fmt=".0f", ax=ax)
plt.xlabel("y_pred")
plt.ylabel("y_true")
plt.show()
# Out:
# Prediction time per sample:  0.0008635879084142129
# Accuracy of RF: 0.9995640745367479
# Precision of RF: 0.9997253085154361
# Recall of RF: 0.99894680583501
# F1-score of RF: 0.9993354642434495
#               precision    recall  f1-score   support
#
# Not Portscan    0.99945   1.00000   0.99973    121888
#     Portscan    1.00000   0.99789   0.99895     31808
#
#     accuracy                        0.99956    153696
#    macro avg    0.99973   0.99895   0.99934    153696
# weighted avg    0.99956   0.99956   0.99956    153696

# %%
# Extra Trees
# calculate the prediction time per sample in milliseconds
start = time.time()
y_predict = et.predict(X_test_fs)
end = time.time()

predict_time_et = (end - start) / len(X_test_fs) * 1000
print('Prediction time per sample: ', predict_time_et)
y_predict = np.where(pd.Series(labelencoder.inverse_transform(y_predict)) == 'Portscan', 'Portscan', 'Not Portscan')

# Evaluation metrics
precision, recall, fscore, none = precision_recall_fscore_support(y_true_ps, y_predict, average='macro')

# Print results
print('Accuracy of ET: ' + str(accuracy_score(y_true_ps, y_predict)))
print('Precision of ET: ' + str(precision))
print('Recall of ET: ' + str(recall))
print('F1-score of ET: ' + str(fscore))
print(classification_report(y_true_ps, y_predict, digits=5))

# Confusion matrix visualization
cm = confusion_matrix(y_true_ps, y_predict)
f, ax = plt.subplots(figsize=(5, 5))
sns.heatmap(cm, annot=True, linewidth=0.5, linecolor="red", fmt=".0f", ax=ax)
plt.xlabel("y_pred")
plt.ylabel("y_true")
plt.show()
# Out:
# Prediction time per sample:  0.002754797494686968
# Accuracy of ET: 0.9995966062877368
# Precision of ET: 0.9997457974579746
# Recall of ET: 0.9990254024144869
# F1-score of ET: 0.9993850922350148
#               precision    recall  f1-score   support
#
# Not Portscan    0.99949   1.00000   0.99975    121888
#     Portscan    1.00000   0.99805   0.99902     31808
#
#     accuracy                        0.99960    153696
#    macro avg    0.99975   0.99903   0.99939    153696
# weighted avg    0.99960   0.99960   0.99960    153696

# %%
# XGBoost
# calculate the prediction time per sample in milliseconds
start = time.time()
y_predict = xg.predict(X_test_fs)
end = time.time()

predict_time_xg = (end - start) / len(X_test_fs) * 1000
print('Prediction time per sample: ', predict_time_xg)
y_predict = np.where(pd.Series(labelencoder.inverse_transform(y_predict)) == 'Portscan', 'Portscan', 'Not Portscan')

# Evaluation metrics
precision, recall, fscore, none = precision_recall_fscore_support(y_true_ps, y_predict, average='macro')

# Print results
print('Accuracy of XG: ' + str(accuracy_score(y_true_ps, y_predict)))
print('Precision of XG: ' + str(precision))
print('Recall of XG: ' + str(recall))
print('F1-score of XG: ' + str(fscore))
print(classification_report(y_true_ps, y_predict, digits=5))

# Confusion matrix visualization
cm = confusion_matrix(y_true_ps, y_predict)
f, ax = plt.subplots(figsize=(5, 5))
sns.heatmap(cm, annot=True, linewidth=0.5, linecolor="red", fmt=".0f", ax=ax)
plt.xlabel("y_pred")
plt.ylabel("y_true")
plt.show()
# Out:
# Prediction time per sample:  0.0001329935617107365
# Accuracy of XG: 0.9995966062877368
# Precision of XG: 0.9997457974579746
# Recall of XG: 0.9990254024144869
# F1-score of XG: 0.9993850922350148
#               precision    recall  f1-score   support
#
# Not Portscan    0.99949   1.00000   0.99975    121888
#     Portscan    1.00000   0.99805   0.99902     31808
#
#     accuracy                        0.99960    153696
#    macro avg    0.99975   0.99903   0.99939    153696
# weighted avg    0.99960   0.99960   0.99960    153696

# %%
# LightGBM
# calculate the prediction time per sample in milliseconds
start = time.time()
y_predict = lgbm.predict(X_test_fs)
end = time.time()

predict_time_lgbm = (end - start) / len(X_test_fs) * 1000
print('Prediction time per sample: ', predict_time_lgbm)
y_predict = np.where(pd.Series(labelencoder.inverse_transform(y_predict)) == 'Portscan', 'Portscan', 'Not Portscan')

# Evaluation metrics
precision, recall, fscore, none = precision_recall_fscore_support(y_true_ps, y_predict, average='macro')

# Print results
print('Accuracy of LGBM: ' + str(accuracy_score(y_true_ps, y_predict)))
print('Precision of LGBM: ' + str(precision))
print('Recall of LGBM: ' + str(recall))
print('F1-score of LGBM: ' + str(fscore))
print(classification_report(y_true_ps, y_predict, digits=5))

# Confusion matrix visualization
cm = confusion_matrix(y_true_ps, y_predict)
f, ax = plt.subplots(figsize=(5, 5))
sns.heatmap(cm, annot=True, linewidth=0.5, linecolor="red", fmt=".0f", ax=ax)
plt.xlabel("y_pred")
plt.ylabel("y_true")
plt.show()
# Out:
# Prediction time per sample:  0.0003371639795758043
# Accuracy of LGBM: 0.9995966062877368
# Precision of LGBM: 0.9997457974579746
# Recall of LGBM: 0.9990254024144869
# F1-score of LGBM: 0.9993850922350148
#               precision    recall  f1-score   support
#
# Not Portscan    0.99949   1.00000   0.99975    121888
#     Portscan    1.00000   0.99805   0.99902     31808
#
#     accuracy                        0.99960    153696
#    macro avg    0.99975   0.99903   0.99939    153696
# weighted avg    0.99960   0.99960   0.99960    153696

# %%
# CatBoost
# calculate the prediction time per sample in milliseconds
start = time.time()
y_predict = cat.predict(X_test_fs)
end = time.time()
print('Prediction time per sample: ', (end - start) / len(X_test_fs)*1000)
y_predict = np.where(pd.Series(labelencoder.inverse_transform(y_predict)) == 'Portscan', 'Portscan', 'Not Portscan')

# Evaluation metrics
precision, recall, fscore, none = precision_recall_fscore_support(y_true_ps, y_predict, average='macro')

# Print results
print('Accuracy of Cat: ' + str(accuracy_score(y_true_ps, y_predict)))
print('Precision of Cat: ' + str(precision))
print('Recall of Cat: ' + str(recall))
print('F1-score of Cat: ' + str(fscore))
print(classification_report(y_true_ps, y_predict, digits=5))

# Confusion matrix visualization
cm = confusion_matrix(y_true_ps, y_predict)
f, ax = plt.subplots(figsize=(5, 5))
sns.heatmap(cm, annot=True, linewidth=0.5, linecolor="red", fmt=".0f", ax=ax)
plt.xlabel("y_pred")
plt.ylabel("y_true")
plt.show()
# Out:
# Prediction time per sample:  0.00013459753846218754
# Accuracy of Cat: 0.9995966062877368
# Precision of Cat: 0.9997457974579746
# Recall of Cat: 0.9990254024144869
# F1-score of Cat: 0.9993850922350148
#               precision    recall  f1-score   support
#
# Not Portscan    0.99949   1.00000   0.99975    121888
#     Portscan    1.00000   0.99805   0.99902     31808
#
#     accuracy                        0.99960    153696
#    macro avg    0.99975   0.99903   0.99939    153696
# weighted avg    0.99960   0.99960   0.99960    153696

# %%
top_3_models
# Out:
# ['et', 'rf', 'lgbm']

# %%
# Ensemble method 1: traditional stacking

# !!! WARNING: always update based used models below based on top_3_models in training !!!
start = time.time()
et_test = et.predict(X_test_fs)
rf_test = rf.predict(X_test_fs)
lgbm_test = lgbm.predict(X_test_fs)

et_test = et_test.reshape(-1, 1)
rf_test = rf_test.reshape(-1, 1)
lgbm_test = lgbm_test.reshape(-1, 1)

x_test = np.concatenate([et_test, rf_test, lgbm_test], axis=1)

y_predict = stk1.predict(x_test)
end = time.time()
print('Prediction time per sample: ', (end - start) / len(X_test_fs)*1000)
y_predict = np.where(pd.Series(labelencoder.inverse_transform(y_predict)) == 'Portscan', 'Portscan', 'Not Portscan')

# Evaluation metrics
precision, recall, fscore, none = precision_recall_fscore_support(y_true_ps, y_predict, average='macro')

# Print results
print('Accuracy of STK Traditional: ' + str(accuracy_score(y_true_ps, y_predict)))
print('Precision of STK Traditional: ' + str(precision))
print('Recall of STK Traditional: ' + str(recall))
print('F1-score of STK Traditional: ' + str(fscore))
print(classification_report(y_true_ps, y_predict, digits=5))

# Confusion matrix visualization
cm = confusion_matrix(y_true_ps, y_predict)
f, ax = plt.subplots(figsize=(5, 5))
sns.heatmap(cm, annot=True, linewidth=0.5, linecolor="red", fmt=".0f", ax=ax)
plt.xlabel("y_pred")
plt.ylabel("y_true")
plt.show()
# Out:
# Prediction time per sample:  0.004336588486467528
# Accuracy of STK Traditional: 0.9995966062877368
# Precision of STK Traditional: 0.9997457974579746
# Recall of STK Traditional: 0.9990254024144869
# F1-score of STK Traditional: 0.9993850922350148
#               precision    recall  f1-score   support
#
# Not Portscan    0.99949   1.00000   0.99975    121888
#     Portscan    1.00000   0.99805   0.99902     31808
#
#     accuracy                        0.99960    153696
#    macro avg    0.99975   0.99903   0.99939    153696
# weighted avg    0.99960   0.99960   0.99960    153696

# %%
# Ensemble method 2: confidence-based stacking

# !!! WARNING: always update based used models below based on top_3_models in training !!!
start = time.time()
et_prob_test = et.predict_proba(X_test_fs)
rf_prob_test = rf.predict_proba(X_test_fs)
lgbm_prob_test = lgbm.predict_proba(X_test_fs)

x_test = np.concatenate([et_prob_test, rf_prob_test, lgbm_prob_test], axis=1)

y_predict = stk2.predict(x_test)
end = time.time()
print('Prediction time per sample: ', (end - start) / len(X_test_fs)*1000)
y_predict = np.where(pd.Series(labelencoder.inverse_transform(y_predict)) == 'Portscan', 'Portscan', 'Not Portscan')

# Evaluation metrics
precision, recall, fscore, none = precision_recall_fscore_support(y_true_ps, y_predict, average='macro')

# Print results
print('Accuracy of STK Confidence: ' + str(accuracy_score(y_true_ps, y_predict)))
print('Precision of STK Confidence: ' + str(precision))
print('Recall of STK Confidence: ' + str(recall))
print('F1-score of STK Confidence: ' + str(fscore))
print(classification_report(y_true_ps, y_predict, digits=5))

# Confusion matrix visualization
cm = confusion_matrix(y_true_ps, y_predict)
f, ax = plt.subplots(figsize=(5, 5))
sns.heatmap(cm, annot=True, linewidth=0.5, linecolor="red", fmt=".0f", ax=ax)
plt.xlabel("y_pred")
plt.ylabel("y_true")
plt.show()
# Out:
# Prediction time per sample:  0.004305618084298554
# Accuracy of STK Confidence: 0.9995640745367479
# Precision of STK Confidence: 0.9997253085154361
# Recall of STK Confidence: 0.99894680583501
# F1-score of STK Confidence: 0.9993354642434495
#               precision    recall  f1-score   support
#
# Not Portscan    0.99945   1.00000   0.99973    121888
#     Portscan    1.00000   0.99789   0.99895     31808
#
#     accuracy                        0.99956    153696
#    macro avg    0.99973   0.99895   0.99934    153696
# weighted avg    0.99956   0.99956   0.99956    153696

# %%
# Ensemble method 3: hybrid stacking

# !!! WARNING: always update based used models below based on top_3_models in training !!!
start = time.time()

et_test = et.predict(X_test_fs)
rf_test = rf.predict(X_test_fs)
lgbm_test = lgbm.predict(X_test_fs)

et_prob_test = et.predict_proba(X_test_fs)
rf_prob_test = rf.predict_proba(X_test_fs)
lgbm_prob_test = lgbm.predict_proba(X_test_fs)

et_test = et_test.reshape(-1, 1)
rf_test = rf_test.reshape(-1, 1)
lgbm_test = lgbm_test.reshape(-1, 1)

x_test = np.concatenate([et_test, rf_test, lgbm_test] + [et_prob_test, rf_prob_test, lgbm_prob_test], axis=1)

y_predict = stk3.predict(x_test)
end = time.time()
print('Prediction time per sample: ', (end - start) / len(X_test_fs)*1000)
y_predict = np.where(pd.Series(labelencoder.inverse_transform(y_predict)) == 'Portscan', 'Portscan', 'Not Portscan')

# Evaluation metrics
precision, recall, fscore, none = precision_recall_fscore_support(y_true_ps, y_predict, average='macro')

# Print results
print('Accuracy of STK Hybrid: ' + str(accuracy_score(y_true_ps, y_predict)))
print('Precision of STK Hybrid: ' + str(precision))
print('Recall of STK Hybrid: ' + str(recall))
print('F1-score of STK Hybrid: ' + str(fscore))
print(classification_report(y_true_ps, y_predict, digits=5))

# Confusion matrix visualization
cm = confusion_matrix(y_true_ps, y_predict)
f, ax = plt.subplots(figsize=(5, 5))
sns.heatmap(cm, annot=True, linewidth=0.5, linecolor="red", fmt=".0f", ax=ax)
plt.xlabel("y_pred")
plt.ylabel("y_true")
plt.show()
# Out:
# Prediction time per sample:  0.007910589960349641
# Accuracy of STK Hybrid: 0.9995966062877368
# Precision of STK Hybrid: 0.9997457974579746
# Recall of STK Hybrid: 0.9990254024144869
# F1-score of STK Hybrid: 0.9993850922350148
#               precision    recall  f1-score   support
#
# Not Portscan    0.99949   1.00000   0.99975    121888
#     Portscan    1.00000   0.99805   0.99902     31808
#
#     accuracy                        0.99960    153696
#    macro avg    0.99975   0.99903   0.99939    153696
# weighted avg    0.99960   0.99960   0.99960    153696

# %% [markdown]
# ## Inference Time

# %%
TRIES = 100

# %%
# this is in milliseconds, not seconds
def calculate_inference_time_in_ms(foo, tries: int):
    times = []
    for _ in range(tries):
        start = time.time()
        foo()
        end = time.time()
        times.append(((end - start) / len(X_test_fs)) * 1000)
    return np.average(times)

# %%
def print_time(name: str, in_ms):
    print(f"Average Inference time for {name}")
    print(in_ms, 'milliseconds')
    print(in_ms / 1000, 'seconds')
    print()

# %% [markdown]
# ## DoS

# %%
dt = joblib.load(f"{DOS_MODEL_LOCATION}/dt_tuned.pkl")
rf = joblib.load(f"{DOS_MODEL_LOCATION}/rf_tuned.pkl")
et = joblib.load(f"{DOS_MODEL_LOCATION}/et_tuned.pkl")
xg = joblib.load(f"{DOS_MODEL_LOCATION}/xg_tuned.pkl")
lgbm = joblib.load(f"{DOS_MODEL_LOCATION}/lgbm_tuned.pkl")
cat = joblib.load(f"{DOS_MODEL_LOCATION}/cat_tuned.pkl")
stk1 = joblib.load(f"{DOS_MODEL_LOCATION}/stk1_tuned.pkl")
stk2 = joblib.load(f"{DOS_MODEL_LOCATION}/stk2_tuned.pkl")
stk3 = joblib.load(f"{DOS_MODEL_LOCATION}/stk3_tuned.pkl")

fs = ['Fwd IAT Min', 'Bwd IAT Mean', 'Fwd Seg Size Min', 'Flow Packets/s', 'Fwd Packets/s', 'Total Length of Bwd Packet', 'Bwd Act Data Pkts', 'Bwd IAT Min', 'Flow IAT Mean', 'FIN Flag Count', 'Bwd Init Win Bytes', 'Fwd Bulk Rate Avg', 'Active Min', 'Fwd Packet Length Max', 'Fwd Packet Length Min', 'Bwd Packets/s', 'Bwd Header Length', 'Bwd Packet Length Mean', 'Subflow Bwd Bytes', 'Flow Duration', 'Flow IAT Min', 'Total Bwd packets', 'Fwd Segment Size Avg', 'FWD Init Win Bytes', 'Packet Length Mean', 'Down/Up Ratio', 'ACK Flag Count', 'Fwd IAT Total', 'SYN Flag Count', 'Bwd Packet Length Max', 'Subflow Fwd Packets', 'Fwd Bytes/Bulk Avg', 'Flow IAT Max', 'Fwd IAT Mean', 'Fwd IAT Std', 'Fwd Header Length']

top_3_models = ['rf', 'xg', 'lgbm']

labelencoder = LabelEncoder()
labelencoder.fit_transform(['Not Slowloris', 'Slowloris'])

X_test_fs = flink_test[fs]
y_test = labelencoder.transform(flink_test_binary_dos['Binary Label'])

# %%
dos_inference_times: list[tuple] = []

# Decision Tree
dos_inference_times.append(("DT", calculate_inference_time_in_ms(lambda: dt.predict(X_test_fs), TRIES)))

# Random Forest
dos_inference_times.append(("RF", calculate_inference_time_in_ms(lambda: rf.predict(X_test_fs), TRIES)))

# Extra Trees
dos_inference_times.append(("ET", calculate_inference_time_in_ms(lambda: et.predict(X_test_fs), TRIES)))

# XGBoost
dos_inference_times.append(("XG", calculate_inference_time_in_ms(lambda: xg.predict(X_test_fs), TRIES)))

# LightGBM
dos_inference_times.append(("LGBM", calculate_inference_time_in_ms(lambda: lgbm.predict(X_test_fs), TRIES)))

# CatBoost
dos_inference_times.append(("Cat", calculate_inference_time_in_ms(lambda: cat.predict(X_test_fs), TRIES)))

# Ensemble 1 (Change based on training's top 3 models results)
def stk1_timer():
    rf_test = rf.predict(X_test_fs)
    xg_test = xg.predict(X_test_fs)
    lgbm_test = lgbm.predict(X_test_fs)

    rf_test = rf_test.reshape(-1, 1)
    xg_test = xg_test.reshape(-1, 1)
    lgbm_test = lgbm_test.reshape(-1, 1)

    x_test = np.concatenate([rf_test, xg_test, lgbm_test], axis=1)

    stk1.predict(x_test)

dos_inference_times.append(("STK Traditional", calculate_inference_time_in_ms(stk1_timer, TRIES)))

# Ensemble 2 (Change based on training's top 3 models results)
def stk2_timer():
    rf_prob_test = rf.predict_proba(X_test_fs)
    xg_prob_test = xg.predict_proba(X_test_fs)
    lgbm_prob_test = lgbm.predict_proba(X_test_fs)

    x_test = np.concatenate([rf_prob_test, xg_prob_test, lgbm_prob_test], axis=1)

    stk2.predict(x_test)

dos_inference_times.append(("STK Confidence", calculate_inference_time_in_ms(stk2_timer, TRIES)))

# Ensemble 3 (Change based on training's top 3 models results)
def stk3_timer():
    rf_test = rf.predict(X_test_fs)
    xg_test = xg.predict(X_test_fs)
    lgbm_test = lgbm.predict(X_test_fs)

    rf_prob_test = rf.predict_proba(X_test_fs)
    xg_prob_test = xg.predict_proba(X_test_fs)
    lgbm_prob_test = lgbm.predict_proba(X_test_fs)

    rf_test = rf_test.reshape(-1, 1)
    xg_test = xg_test.reshape(-1, 1)
    lgbm_test = lgbm_test.reshape(-1, 1)

    x_test = np.concatenate([rf_test, xg_test, lgbm_test] + [rf_prob_test, xg_prob_test, lgbm_prob_test], axis=1)

    stk3.predict(x_test)

dos_inference_times.append(("STK Hybrid", calculate_inference_time_in_ms(stk3_timer, TRIES)))

# %%
dos_times = sorted(dos_inference_times, key=lambda x: x[1])
dos_times
# Out:
# [('XG', 0.00010066429339620736),
#  ('DT', 0.00010212270227690771),
#  ('Cat', 0.00014009792221950142),
#  ('LGBM', 0.0004986475035470649),
#  ('ET', 0.000827747699421643),
#  ('RF', 0.0014065719819828394),
#  ('STK Confidence', 0.0021251716540303055),
#  ('STK Traditional', 0.0024215067932066166),
#  ('STK Hybrid', 0.004266913054934051)]

# %%
[[a, format(b, '.5f')] for a, b in dos_times]
# Out:
# [['XG', '0.00010'],
#  ['DT', '0.00010'],
#  ['Cat', '0.00014'],
#  ['LGBM', '0.00050'],
#  ['ET', '0.00083'],
#  ['RF', '0.00141'],
#  ['STK Confidence', '0.00213'],
#  ['STK Traditional', '0.00242'],
#  ['STK Hybrid', '0.00427']]

# %%
dos_inference_times: list[tuple] = []

# Decision Tree
dos_inference_times.append(("DT", calculate_inference_time_in_ms(lambda: dt.predict(X_test_fs), TRIES)))

# Random Forest
dos_inference_times.append(("RF", calculate_inference_time_in_ms(lambda: rf.predict(X_test_fs), TRIES)))

# Extra Trees
dos_inference_times.append(("ET", calculate_inference_time_in_ms(lambda: et.predict(X_test_fs), TRIES)))

# XGBoost
dos_inference_times.append(("XG", calculate_inference_time_in_ms(lambda: xg.predict(X_test_fs), TRIES)))

# LightGBM
dos_inference_times.append(("LGBM", calculate_inference_time_in_ms(lambda: lgbm.predict(X_test_fs), TRIES)))

# CatBoost
dos_inference_times.append(("Cat", calculate_inference_time_in_ms(lambda: cat.predict(X_test_fs), TRIES)))

# Ensemble 1 (Change based on training's top 3 models results)
def stk1_timer():
    rf_test = rf.predict(X_test_fs)
    xg_test = xg.predict(X_test_fs)
    lgbm_test = lgbm.predict(X_test_fs)

    rf_test = rf_test.reshape(-1, 1)
    xg_test = xg_test.reshape(-1, 1)
    lgbm_test = lgbm_test.reshape(-1, 1)

    x_test = np.concatenate([rf_test, xg_test, lgbm_test], axis=1)

    stk1.predict(x_test)

dos_inference_times.append(("STK Traditional", calculate_inference_time_in_ms(stk1_timer, TRIES)))

# Ensemble 2 (Change based on training's top 3 models results)
def stk2_timer():
    rf_prob_test = rf.predict_proba(X_test_fs)
    xg_prob_test = xg.predict_proba(X_test_fs)
    lgbm_prob_test = lgbm.predict_proba(X_test_fs)

    x_test = np.concatenate([rf_prob_test, xg_prob_test, lgbm_prob_test], axis=1)

    stk2.predict(x_test)

dos_inference_times.append(("STK Confidence", calculate_inference_time_in_ms(stk2_timer, TRIES)))

# Ensemble 3 (Change based on training's top 3 models results)
def stk3_timer():
    rf_test = rf.predict(X_test_fs)
    xg_test = xg.predict(X_test_fs)
    lgbm_test = lgbm.predict(X_test_fs)

    rf_prob_test = rf.predict_proba(X_test_fs)
    xg_prob_test = xg.predict_proba(X_test_fs)
    lgbm_prob_test = lgbm.predict_proba(X_test_fs)

    rf_test = rf_test.reshape(-1, 1)
    xg_test = xg_test.reshape(-1, 1)
    lgbm_test = lgbm_test.reshape(-1, 1)

    x_test = np.concatenate([rf_test, xg_test, lgbm_test] + [rf_prob_test, xg_prob_test, lgbm_prob_test], axis=1)

    stk3.predict(x_test)

dos_inference_times.append(("STK Hybrid", calculate_inference_time_in_ms(stk3_timer, TRIES)))

# %%
dos_times = sorted(dos_inference_times, key=lambda x: x[1])
dos_times
# Out:
# [('XG', 9.746949436414894e-05),
#  ('DT', 0.00010107589802989208),
#  ('Cat', 0.00014754501253819432),
#  ('LGBM', 0.0005238073525666049),
#  ('ET', 0.0008764895124780917),
#  ('RF', 0.0014659438019317065),
#  ('STK Confidence', 0.002098328560162603),
#  ('STK Traditional', 0.0023168730141345643),
#  ('STK Hybrid', 0.004200042426499282)]

# %%
[[a, format(b, '.5f')] for a, b in dos_times]
# Out:
# [['XG', '0.00010'],
#  ['DT', '0.00010'],
#  ['Cat', '0.00015'],
#  ['LGBM', '0.00052'],
#  ['ET', '0.00088'],
#  ['RF', '0.00147'],
#  ['STK Confidence', '0.00210'],
#  ['STK Traditional', '0.00232'],
#  ['STK Hybrid', '0.00420']]

# %% [markdown]
# ## Port Scan

# %%
dt = joblib.load(f"{PS_MODEL_LOCATION}/dt_tuned.pkl")
rf = joblib.load(f"{PS_MODEL_LOCATION}/rf_tuned.pkl")
et = joblib.load(f"{PS_MODEL_LOCATION}/et_tuned.pkl")
xg = joblib.load(f"{PS_MODEL_LOCATION}/xg_tuned.pkl")
lgbm = joblib.load(f"{PS_MODEL_LOCATION}/lgbm_tuned.pkl")
cat = joblib.load(f"{PS_MODEL_LOCATION}/cat_tuned.pkl")
stk1 = joblib.load(f"{PS_MODEL_LOCATION}/stk1_tuned.pkl")
stk2 = joblib.load(f"{PS_MODEL_LOCATION}/stk2_tuned.pkl")
stk3 = joblib.load(f"{PS_MODEL_LOCATION}/stk3_tuned.pkl")

fs = ['Bwd RST Flags', 'FWD Init Win Bytes', 'RST Flag Count', 'Flow Duration', 'Packet Length Max', 'Flow Packets/s', 'Protocol', 'Total Length of Fwd Packet', 'Flow IAT Max', 'Fwd Seg Size Min', 'Average Packet Size', 'Packet Length Mean', 'Fwd Packet Length Max', 'Bwd IAT Mean', 'Total Fwd Packet', 'Flow Bytes/s', 'Fwd Act Data Pkts', 'Bwd Packets/s', 'Bwd Packet Length Std', 'Fwd IAT Total', 'Flow IAT Mean', 'Flow IAT Min', 'Fwd Segment Size Avg', 'Fwd Header Length', 'Bwd Packet Length Mean', 'Packet Length Std', 'Fwd IAT Min', 'Packet Length Variance', 'Bwd IAT Max']

top_3_models = ['et', 'rf', 'lgbm']

labelencoder = LabelEncoder()
labelencoder.fit_transform(['Not Portscan', 'Portscan'])

X_test_fs = flink_test[fs]
y_test = labelencoder.transform(flink_test_binary_ps['Binary Label'])

# %%
ps_inference_times: list[tuple] = []

# Decision Tree
ps_inference_times.append(("DT", calculate_inference_time_in_ms(lambda: dt.predict(X_test_fs), TRIES)))

# Random Forest
ps_inference_times.append(("RF", calculate_inference_time_in_ms(lambda: rf.predict(X_test_fs), TRIES)))

# Extra Trees
ps_inference_times.append(("ET", calculate_inference_time_in_ms(lambda: et.predict(X_test_fs), TRIES)))

# XGBoost
ps_inference_times.append(("XG", calculate_inference_time_in_ms(lambda: xg.predict(X_test_fs), TRIES)))

# LightGBM
ps_inference_times.append(("LGBM", calculate_inference_time_in_ms(lambda: lgbm.predict(X_test_fs), TRIES)))

# CatBoost
ps_inference_times.append(("Cat", calculate_inference_time_in_ms(lambda: cat.predict(X_test_fs), TRIES)))

# Ensemble 1 (Change based on training's top 3 models results)
def stk1_timer():
    et_test = et.predict(X_test_fs)
    rf_test = rf.predict(X_test_fs)
    lgbm_test = lgbm.predict(X_test_fs)

    et_test = et_test.reshape(-1, 1)
    rf_test = rf_test.reshape(-1, 1)
    lgbm_test = lgbm_test.reshape(-1, 1)

    x_test = np.concatenate([et_test, rf_test, lgbm_test], axis=1)

    stk1.predict(x_test)

ps_inference_times.append(("STK Traditional", calculate_inference_time_in_ms(stk1_timer, TRIES)))

# Ensemble 2 (Change based on training's top 3 models results)
def stk2_timer():
    et_prob_test = et.predict_proba(X_test_fs)
    rf_prob_test = rf.predict_proba(X_test_fs)
    lgbm_prob_test = lgbm.predict_proba(X_test_fs)

    x_test = np.concatenate([et_prob_test, rf_prob_test, lgbm_prob_test], axis=1)

    stk2.predict(x_test)

ps_inference_times.append(("STK Confidence", calculate_inference_time_in_ms(stk2_timer, TRIES)))

# Ensemble 3 (Change based on training's top 3 models results)
def stk3_timer():
    et_test = et.predict(X_test_fs)
    rf_test = rf.predict(X_test_fs)
    lgbm_test = lgbm.predict(X_test_fs)

    et_prob_test = et.predict_proba(X_test_fs)
    rf_prob_test = rf.predict_proba(X_test_fs)
    lgbm_prob_test = lgbm.predict_proba(X_test_fs)

    et_test = et_test.reshape(-1, 1)
    rf_test = rf_test.reshape(-1, 1)
    lgbm_test = lgbm_test.reshape(-1, 1)

    x_test = np.concatenate([et_test, rf_test, lgbm_test] + [et_prob_test, rf_prob_test, lgbm_prob_test], axis=1)

    stk3.predict(x_test)

ps_inference_times.append(("STK Hybrid", calculate_inference_time_in_ms(stk3_timer, TRIES)))

# %%
ps_times = sorted(ps_inference_times, key=lambda x: x[1])
ps_times
# Out:
# [('DT', 8.318349083041291e-05),
#  ('XG', 8.553131567843625e-05),
#  ('Cat', 0.00011594825279407394),
#  ('LGBM', 0.0003177353845842923),
#  ('RF', 0.0007984804289305729),
#  ('ET', 0.0029891115531260194),
#  ('STK Confidence', 0.004048482554668241),
#  ('STK Traditional', 0.004158564347811796),
#  ('STK Hybrid', 0.008194513949359083)]

# %%
[[a, format(b, '.5f')] for a, b in ps_times]
# Out:
# [['DT', '0.00008'],
#  ['XG', '0.00009'],
#  ['Cat', '0.00012'],
#  ['LGBM', '0.00032'],
#  ['RF', '0.00080'],
#  ['ET', '0.00299'],
#  ['STK Confidence', '0.00405'],
#  ['STK Traditional', '0.00416'],
#  ['STK Hybrid', '0.00819']]

# %% [markdown]
# # Analysis

# %%
flink_train = pd.read_csv('../datasets/output/train_final.csv', index_col=0)
flink_train
# Out:
#                                              Src IP  Src Port         Dst IP  \
# Flow ID
# 6b19ab16-1dbb-4f73-ba57-3dfddf145bce  192.168.10.17     49453   192.168.10.3
# 61e29423-21b4-4724-ba8b-3f62c917193c  192.168.10.17     46124   192.168.10.3
# 95e9bc0a-0c9c-4cae-8732-ba6bcbba31f5  192.168.10.17     49454   192.168.10.3
# 02570213-ef94-4b09-8bd1-dd8310f90311  192.168.10.17     46126   192.168.10.3
# aadcae10-dcf9-4545-a988-f24bf6da8637  192.168.10.17     49460   192.168.10.3
# ...                                             ...       ...            ...
# 34e22084-eddc-425d-a027-f2ada71f489b  192.168.10.50     42910   192.168.10.3
# 047c1c20-7c9d-4b0d-b142-512944fb426f   192.168.10.8     10414   192.168.10.3
# 5d4f98d3-b002-4720-938e-abcbeba6ec2f   192.168.10.8     51617   192.168.10.3
# f068575e-7060-485f-8875-89dc8982fa94   192.168.10.8       123   192.168.10.3
# a0ed6ab8-18db-49bf-b18f-e6f0007ad563  192.168.10.51     59581  162.213.33.50
#
#                                       Dst Port  Protocol  \
# Flow ID
# 6b19ab16-1dbb-4f73-ba57-3dfddf145bce       389         6
# 61e29423-21b4-4724-ba8b-3f62c917193c        88         6
# 95e9bc0a-0c9c-4cae-8732-ba6bcbba31f5       389         6
# 02570213-ef94-4b09-8bd1-dd8310f90311        88         6
# aadcae10-dcf9-4545-a988-f24bf6da8637       389         6
# ...                                        ...       ...
# 34e22084-eddc-425d-a027-f2ada71f489b       389         6
# 047c1c20-7c9d-4b0d-b142-512944fb426f       445         6
# 5d4f98d3-b002-4720-938e-abcbeba6ec2f        53        17
# f068575e-7060-485f-8875-89dc8982fa94       123        17
# a0ed6ab8-18db-49bf-b18f-e6f0007ad563       443         6
#
#                                                        Timestamp  \
# Flow ID
# 6b19ab16-1dbb-4f73-ba57-3dfddf145bce  2017-07-05 11:42:48.570260
# 61e29423-21b4-4724-ba8b-3f62c917193c  2017-07-05 11:42:48.583448
# 95e9bc0a-0c9c-4cae-8732-ba6bcbba31f5  2017-07-05 11:42:48.571557
# 02570213-ef94-4b09-8bd1-dd8310f90311  2017-07-05 11:42:48.627714
# aadcae10-dcf9-4545-a988-f24bf6da8637  2017-07-05 11:42:49.114734
# ...                                                          ...
# 34e22084-eddc-425d-a027-f2ada71f489b  2017-07-07 20:02:38.387716
# 047c1c20-7c9d-4b0d-b142-512944fb426f  2017-07-07 20:02:38.575222
# 5d4f98d3-b002-4720-938e-abcbeba6ec2f  2017-07-07 20:02:38.574765
# f068575e-7060-485f-8875-89dc8982fa94  2017-07-07 20:02:38.913542
# a0ed6ab8-18db-49bf-b18f-e6f0007ad563  2017-07-07 20:02:40.977798
#
#                                       Flow Duration  Total Fwd Packet  \
# Flow ID
# 6b19ab16-1dbb-4f73-ba57-3dfddf145bce          527.0                12
# 61e29423-21b4-4724-ba8b-3f62c917193c         1194.0                11
# 95e9bc0a-0c9c-4cae-8732-ba6bcbba31f5        15185.0                16
# 02570213-ef94-4b09-8bd1-dd8310f90311         1186.0                10
# aadcae10-dcf9-4545-a988-f24bf6da8637          483.0                12
# ...                                             ...               ...
# 34e22084-eddc-425d-a027-f2ada71f489b        72263.0                 8
# 047c1c20-7c9d-4b0d-b142-512944fb426f       247267.0                16
# 5d4f98d3-b002-4720-938e-abcbeba6ec2f          261.0                 2
# f068575e-7060-485f-8875-89dc8982fa94          125.0                 2
# a0ed6ab8-18db-49bf-b18f-e6f0007ad563       191310.0                 3
#
#                                       Total Bwd packets  \
# Flow ID
# 6b19ab16-1dbb-4f73-ba57-3dfddf145bce                  7
# 61e29423-21b4-4724-ba8b-3f62c917193c                  9
# 95e9bc0a-0c9c-4cae-8732-ba6bcbba31f5                 12
# 02570213-ef94-4b09-8bd1-dd8310f90311                  9
# aadcae10-dcf9-4545-a988-f24bf6da8637                  7
# ...                                                 ...
# 34e22084-eddc-425d-a027-f2ada71f489b                  4
# 047c1c20-7c9d-4b0d-b142-512944fb426f                 12
# 5d4f98d3-b002-4720-938e-abcbeba6ec2f                  2
# f068575e-7060-485f-8875-89dc8982fa94                  2
# a0ed6ab8-18db-49bf-b18f-e6f0007ad563                  2
#
#                                       Total Length of Fwd Packet  ...  \
# Flow ID                                                           ...
# 6b19ab16-1dbb-4f73-ba57-3dfddf145bce                       172.0  ...
# 61e29423-21b4-4724-ba8b-3f62c917193c                      3150.0  ...
# 95e9bc0a-0c9c-4cae-8732-ba6bcbba31f5                      3452.0  ...
# 02570213-ef94-4b09-8bd1-dd8310f90311                      3150.0  ...
# aadcae10-dcf9-4545-a988-f24bf6da8637                       172.0  ...
# ...                                                          ...  ...
# 34e22084-eddc-425d-a027-f2ada71f489b                      1612.0  ...
# 047c1c20-7c9d-4b0d-b142-512944fb426f                      1624.0  ...
# 5d4f98d3-b002-4720-938e-abcbeba6ec2f                        64.0  ...
# f068575e-7060-485f-8875-89dc8982fa94                        96.0  ...
# a0ed6ab8-18db-49bf-b18f-e6f0007ad563                       148.0  ...
#
#                                       Idle Max  Idle Min  ICMP Code  \
# Flow ID
# 6b19ab16-1dbb-4f73-ba57-3dfddf145bce       0.0       0.0          0
# 61e29423-21b4-4724-ba8b-3f62c917193c       0.0       0.0          0
# 95e9bc0a-0c9c-4cae-8732-ba6bcbba31f5       0.0       0.0          0
# 02570213-ef94-4b09-8bd1-dd8310f90311       0.0       0.0          0
# aadcae10-dcf9-4545-a988-f24bf6da8637       0.0       0.0          0
# ...                                        ...       ...        ...
# 34e22084-eddc-425d-a027-f2ada71f489b       0.0       0.0          0
# 047c1c20-7c9d-4b0d-b142-512944fb426f       0.0       0.0          0
# 5d4f98d3-b002-4720-938e-abcbeba6ec2f       0.0       0.0          0
# f068575e-7060-485f-8875-89dc8982fa94       0.0       0.0          0
# a0ed6ab8-18db-49bf-b18f-e6f0007ad563       0.0       0.0          0
#
#                                       ICMP Type  Fwd TCP Retrans. Count  \
# Flow ID
# 6b19ab16-1dbb-4f73-ba57-3dfddf145bce          0                       6
# 61e29423-21b4-4724-ba8b-3f62c917193c          0                       5
# 95e9bc0a-0c9c-4cae-8732-ba6bcbba31f5          0                       8
# 02570213-ef94-4b09-8bd1-dd8310f90311          0                       6
# aadcae10-dcf9-4545-a988-f24bf6da8637          0                       6
# ...                                         ...                     ...
# 34e22084-eddc-425d-a027-f2ada71f489b          0                       4
# 047c1c20-7c9d-4b0d-b142-512944fb426f          0                       8
# 5d4f98d3-b002-4720-938e-abcbeba6ec2f          0                       0
# f068575e-7060-485f-8875-89dc8982fa94          0                       0
# a0ed6ab8-18db-49bf-b18f-e6f0007ad563          0                       0
#
#                                       Bwd TCP Retrans. Count  \
# Flow ID
# 6b19ab16-1dbb-4f73-ba57-3dfddf145bce                       3
# 61e29423-21b4-4724-ba8b-3f62c917193c                       4
# 95e9bc0a-0c9c-4cae-8732-ba6bcbba31f5                       4
# 02570213-ef94-4b09-8bd1-dd8310f90311                       4
# aadcae10-dcf9-4545-a988-f24bf6da8637                       3
# ...                                                      ...
# 34e22084-eddc-425d-a027-f2ada71f489b                       2
# 047c1c20-7c9d-4b0d-b142-512944fb426f                       6
# 5d4f98d3-b002-4720-938e-abcbeba6ec2f                       0
# f068575e-7060-485f-8875-89dc8982fa94                       0
# a0ed6ab8-18db-49bf-b18f-e6f0007ad563                       0
#
#                                       Total TCP Retrans. Count  \
# Flow ID
# 6b19ab16-1dbb-4f73-ba57-3dfddf145bce                         9
# 61e29423-21b4-4724-ba8b-3f62c917193c                         9
# 95e9bc0a-0c9c-4cae-8732-ba6bcbba31f5                        12
# 02570213-ef94-4b09-8bd1-dd8310f90311                        10
# aadcae10-dcf9-4545-a988-f24bf6da8637                         9
# ...                                                        ...
# 34e22084-eddc-425d-a027-f2ada71f489b                         6
# 047c1c20-7c9d-4b0d-b142-512944fb426f                        14
# 5d4f98d3-b002-4720-938e-abcbeba6ec2f                         0
# f068575e-7060-485f-8875-89dc8982fa94                         0
# a0ed6ab8-18db-49bf-b18f-e6f0007ad563                         0
#
#                                       Total Connection Flow Time   Label  \
# Flow ID
# 6b19ab16-1dbb-4f73-ba57-3dfddf145bce                         527  Benign
# 61e29423-21b4-4724-ba8b-3f62c917193c                        1194  Benign
# 95e9bc0a-0c9c-4cae-8732-ba6bcbba31f5                       15185  Benign
# 02570213-ef94-4b09-8bd1-dd8310f90311                        1186  Benign
# aadcae10-dcf9-4545-a988-f24bf6da8637                         483  Benign
# ...                                                          ...     ...
# 34e22084-eddc-425d-a027-f2ada71f489b                   126534055  Benign
# 047c1c20-7c9d-4b0d-b142-512944fb426f                      247267  Benign
# 5d4f98d3-b002-4720-938e-abcbeba6ec2f                         261  Benign
# f068575e-7060-485f-8875-89dc8982fa94                         125  Benign
# a0ed6ab8-18db-49bf-b18f-e6f0007ad563                      191310  Benign
#
#                                       Old Index
# Flow ID
# 6b19ab16-1dbb-4f73-ba57-3dfddf145bce     807500
# 61e29423-21b4-4724-ba8b-3f62c917193c     582651
# 95e9bc0a-0c9c-4cae-8732-ba6bcbba31f5    1038592
# 02570213-ef94-4b09-8bd1-dd8310f90311     953244
# aadcae10-dcf9-4545-a988-f24bf6da8637     780889
# ...                                         ...
# 34e22084-eddc-425d-a027-f2ada71f489b     815720
# 047c1c20-7c9d-4b0d-b142-512944fb426f     688082
# 5d4f98d3-b002-4720-938e-abcbeba6ec2f     877141
# f068575e-7060-485f-8875-89dc8982fa94     941811
# a0ed6ab8-18db-49bf-b18f-e6f0007ad563     566175
#
# [616981 rows x 94 columns]

# %%
X_train_fs = flink_train[fs]
y_train = labelencoder.transform(flink_train['Label'])

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report,confusion_matrix,precision_recall_fscore_support, accuracy_score

# Ensemble method 3: hybrid stacking

# !!! WARNING: always update based used models below based on top_3_models in training !!!
start = time.time()

et_test = et.predict(X_test_fs)
rf_test = rf.predict(X_test_fs)
cat_test = cat.predict(X_test_fs)

et_prob_test = et.predict_proba(X_test_fs)
rf_prob_test = rf.predict_proba(X_test_fs)
cat_prob_test = cat.predict_proba(X_test_fs)

et_test = et_test.reshape(-1, 1)
rf_test = rf_test.reshape(-1, 1)
cat_test = cat_test.reshape(-1, 1)

x_test = np.concatenate([et_test, rf_test, cat_test] + [et_prob_test, rf_prob_test, cat_prob_test], axis=1)

y_predict = stk3.predict(x_test)
end = time.time()
print('Prediction time per sample: ', (end - start) / len(X_test_fs)*1000)
y_predict = np.where(pd.Series(labelencoder.inverse_transform(y_predict)) == 'Slowloris', 'Slowloris', 'Not Slowloris')

# Evaluation metrics
precision, recall, fscore, none = precision_recall_fscore_support(y_true_dos, y_predict, average='macro')

# Print results
print('Accuracy of STK Hybrid: ' + str(accuracy_score(y_true_dos, y_predict)))
print('Precision of STK Hybrid: ' + str(precision))
print('Recall of STK Hybrid: ' + str(recall))
print('F1-score of STK Hybrid: ' + str(fscore))
print(classification_report(y_true_dos, y_predict, digits=5))

# Confusion matrix visualization
cm = confusion_matrix(y_true_dos, y_predict)
f, ax = plt.subplots(figsize=(5, 5))
sns.heatmap(cm, annot=True, linewidth=0.5, linecolor="red", fmt=".0f", ax=ax)
plt.xlabel("y_pred")
plt.ylabel("y_true")
plt.show()
# Out:
# Prediction time per sample:  0.0124940391439959
# Accuracy of STK Hybrid: 0.9977748571874715
# Precision of STK Hybrid: 0.9988816366038378
# Recall of STK Hybrid: 0.8497363796133568
# F1-score of STK Hybrid: 0.9110224052633935
#                precision    recall  f1-score   support
#
# Not Slowloris    0.99776   1.00000   0.99888    152560
#     Slowloris    1.00000   0.69947   0.82316      1138
#
#      accuracy                        0.99777    153698
#     macro avg    0.99888   0.84974   0.91102    153698
#  weighted avg    0.99778   0.99777   0.99758    153698

# %%
X_test_fs
# Out:
#                                       Fwd Seg Size Min  Bwd RST Flags  \
# Flow ID
# 67fe01c7-f0d3-40ae-9734-11b87bbad3bd                20              0
# 8ae50662-7e0b-4ead-8e28-239831b9ef68                32              0
# 25b06579-d96c-48a0-a51d-7a430954b846                20              0
# 9e187a13-ffe2-4a44-8a8c-b624bc5b770d                20              0
# 5edd0384-aa65-487b-b9e5-33ebc63cbe0f                20              0
# ...                                                ...            ...
# 9007ea08-91f4-4f7e-88bb-2028c6a83115                 8              0
# f94bf22a-875b-4e88-ad42-ffae18afde65                 8              0
# f62720f2-cdfe-4fa3-b54e-530f595e0007                 8              0
# 14f89ec0-bf3e-4168-ac3c-b9177edfbec6                 8              0
# d3c596c1-d404-4517-ab40-c127fc8b44a3                 8              0
#
#                                       Flow Duration  Bwd Segment Size Avg  \
# Flow ID
# 67fe01c7-f0d3-40ae-9734-11b87bbad3bd        85742.0            849.666667
# 8ae50662-7e0b-4ead-8e28-239831b9ef68      1038445.0            329.166667
# 25b06579-d96c-48a0-a51d-7a430954b846        70672.0            171.600000
# 9e187a13-ffe2-4a44-8a8c-b624bc5b770d       217279.0            585.000000
# 5edd0384-aa65-487b-b9e5-33ebc63cbe0f       219470.0            563.125000
# ...                                             ...                   ...
# 9007ea08-91f4-4f7e-88bb-2028c6a83115          150.0             23.000000
# f94bf22a-875b-4e88-ad42-ffae18afde65          195.0             23.000000
# f62720f2-cdfe-4fa3-b54e-530f595e0007          176.0             23.000000
# 14f89ec0-bf3e-4168-ac3c-b9177edfbec6          141.0             23.000000
# d3c596c1-d404-4517-ab40-c127fc8b44a3          188.0             23.000000
#
#                                       Bwd Act Data Pkts  Protocol  \
# Flow ID
# 67fe01c7-f0d3-40ae-9734-11b87bbad3bd                  4         6
# 8ae50662-7e0b-4ead-8e28-239831b9ef68                  5         6
# 25b06579-d96c-48a0-a51d-7a430954b846                  1         6
# 9e187a13-ffe2-4a44-8a8c-b624bc5b770d                  7         6
# 5edd0384-aa65-487b-b9e5-33ebc63cbe0f                  5         6
# ...                                                 ...       ...
# 9007ea08-91f4-4f7e-88bb-2028c6a83115                  2        17
# f94bf22a-875b-4e88-ad42-ffae18afde65                  2        17
# f62720f2-cdfe-4fa3-b54e-530f595e0007                  2        17
# 14f89ec0-bf3e-4168-ac3c-b9177edfbec6                  2        17
# d3c596c1-d404-4517-ab40-c127fc8b44a3                  2        17
#
#                                       Bwd Packet Length Max  Flow IAT Max  \
# Flow ID
# 67fe01c7-f0d3-40ae-9734-11b87bbad3bd                 2920.0       25870.0
# 8ae50662-7e0b-4ead-8e28-239831b9ef68                 1448.0      292001.0
# 25b06579-d96c-48a0-a51d-7a430954b846                  858.0       23364.0
# 9e187a13-ffe2-4a44-8a8c-b624bc5b770d                 1877.0       50457.0
# 5edd0384-aa65-487b-b9e5-33ebc63cbe0f                 1460.0       50485.0
# ...                                                     ...           ...
# 9007ea08-91f4-4f7e-88bb-2028c6a83115                   23.0         145.0
# f94bf22a-875b-4e88-ad42-ffae18afde65                   23.0         181.0
# f62720f2-cdfe-4fa3-b54e-530f595e0007                   23.0         126.0
# 14f89ec0-bf3e-4168-ac3c-b9177edfbec6                   23.0         135.0
# d3c596c1-d404-4517-ab40-c127fc8b44a3                   23.0         185.0
#
#                                       Fwd IAT Min  Bwd Packet Length Mean  \
# Flow ID
# 67fe01c7-f0d3-40ae-9734-11b87bbad3bd          4.0              849.666667
# 8ae50662-7e0b-4ead-8e28-239831b9ef68        217.0              329.166667
# 25b06579-d96c-48a0-a51d-7a430954b846        109.0              171.600000
# 9e187a13-ffe2-4a44-8a8c-b624bc5b770d        375.0              585.000000
# 5edd0384-aa65-487b-b9e5-33ebc63cbe0f        217.0              563.125000
# ...                                           ...                     ...
# 9007ea08-91f4-4f7e-88bb-2028c6a83115          3.0               23.000000
# f94bf22a-875b-4e88-ad42-ffae18afde65         13.0               23.000000
# f62720f2-cdfe-4fa3-b54e-530f595e0007          2.0               23.000000
# 14f89ec0-bf3e-4168-ac3c-b9177edfbec6          3.0               23.000000
# d3c596c1-d404-4517-ab40-c127fc8b44a3          2.0               23.000000
#
#                                       ...  Fwd Header Length  \
# Flow ID                               ...
# 67fe01c7-f0d3-40ae-9734-11b87bbad3bd  ...                212
# 8ae50662-7e0b-4ead-8e28-239831b9ef68  ...                328
# 25b06579-d96c-48a0-a51d-7a430954b846  ...                112
# 9e187a13-ffe2-4a44-8a8c-b624bc5b770d  ...                192
# 5edd0384-aa65-487b-b9e5-33ebc63cbe0f  ...                172
# ...                                   ...                ...
# 9007ea08-91f4-4f7e-88bb-2028c6a83115  ...                 16
# f94bf22a-875b-4e88-ad42-ffae18afde65  ...                 16
# f62720f2-cdfe-4fa3-b54e-530f595e0007  ...                 16
# 14f89ec0-bf3e-4168-ac3c-b9177edfbec6  ...                 16
# d3c596c1-d404-4517-ab40-c127fc8b44a3  ...                 16
#
#                                       Bwd Header Length  \
# Flow ID
# 67fe01c7-f0d3-40ae-9734-11b87bbad3bd                132
# 8ae50662-7e0b-4ead-8e28-239831b9ef68                392
# 25b06579-d96c-48a0-a51d-7a430954b846                112
# 9e187a13-ffe2-4a44-8a8c-b624bc5b770d                224
# 5edd0384-aa65-487b-b9e5-33ebc63cbe0f                164
# ...                                                 ...
# 9007ea08-91f4-4f7e-88bb-2028c6a83115                 16
# f94bf22a-875b-4e88-ad42-ffae18afde65                 16
# f62720f2-cdfe-4fa3-b54e-530f595e0007                 16
# 14f89ec0-bf3e-4168-ac3c-b9177edfbec6                 16
# d3c596c1-d404-4517-ab40-c127fc8b44a3                 16
#
#                                       Fwd Packet Length Min  Bwd Packets/s  \
# Flow ID
# 67fe01c7-f0d3-40ae-9734-11b87bbad3bd                    0.0      69.977374
# 8ae50662-7e0b-4ead-8e28-239831b9ef68                    0.0      11.555740
# 25b06579-d96c-48a0-a51d-7a430954b846                    0.0      70.749377
# 9e187a13-ffe2-4a44-8a8c-b624bc5b770d                    0.0      50.626153
# 5edd0384-aa65-487b-b9e5-33ebc63cbe0f                    0.0      36.451451
# ...                                                     ...            ...
# 9007ea08-91f4-4f7e-88bb-2028c6a83115                   23.0   13333.333333
# f94bf22a-875b-4e88-ad42-ffae18afde65                   23.0   10256.410256
# f62720f2-cdfe-4fa3-b54e-530f595e0007                   23.0   11363.636364
# 14f89ec0-bf3e-4168-ac3c-b9177edfbec6                   23.0   14184.397163
# d3c596c1-d404-4517-ab40-c127fc8b44a3                   23.0   10638.297872
#
#                                       Bwd Packet Length Std    Fwd IAT Std  \
# Flow ID
# 67fe01c7-f0d3-40ae-9734-11b87bbad3bd            1149.916461   11978.634714
# 8ae50662-7e0b-4ead-8e28-239831b9ef68             553.194826  119618.922107
# 25b06579-d96c-48a0-a51d-7a430954b846             383.709265   13589.575573
# 9e187a13-ffe2-4a44-8a8c-b624bc5b770d             785.136167   26965.015766
# 5edd0384-aa65-487b-b9e5-33ebc63cbe0f             743.163785   28284.313199
# ...                                                     ...            ...
# 9007ea08-91f4-4f7e-88bb-2028c6a83115               0.000000       0.000000
# f94bf22a-875b-4e88-ad42-ffae18afde65               0.000000       0.000000
# f62720f2-cdfe-4fa3-b54e-530f595e0007               0.000000       0.000000
# 14f89ec0-bf3e-4168-ac3c-b9177edfbec6               0.000000       0.000000
# d3c596c1-d404-4517-ab40-c127fc8b44a3               0.000000       0.000000
#
#                                       Fwd Bulk Rate Avg  Total Bwd packets  \
# Flow ID
# 67fe01c7-f0d3-40ae-9734-11b87bbad3bd                0.0                  6
# 8ae50662-7e0b-4ead-8e28-239831b9ef68                0.0                 12
# 25b06579-d96c-48a0-a51d-7a430954b846                0.0                  5
# 9e187a13-ffe2-4a44-8a8c-b624bc5b770d                0.0                 11
# 5edd0384-aa65-487b-b9e5-33ebc63cbe0f                0.0                  8
# ...                                                 ...                ...
# 9007ea08-91f4-4f7e-88bb-2028c6a83115                0.0                  2
# f94bf22a-875b-4e88-ad42-ffae18afde65                0.0                  2
# f62720f2-cdfe-4fa3-b54e-530f595e0007                0.0                  2
# 14f89ec0-bf3e-4168-ac3c-b9177edfbec6                0.0                  2
# d3c596c1-d404-4517-ab40-c127fc8b44a3                0.0                  2
#
#                                       Subflow Fwd Packets  Bwd IAT Max
# Flow ID
# 67fe01c7-f0d3-40ae-9734-11b87bbad3bd                  0.0      36090.0
# 8ae50662-7e0b-4ead-8e28-239831b9ef68                  0.0     292001.0
# 25b06579-d96c-48a0-a51d-7a430954b846                  0.0      23512.0
# 9e187a13-ffe2-4a44-8a8c-b624bc5b770d                  0.0      97524.0
# 5edd0384-aa65-487b-b9e5-33ebc63cbe0f                  0.0     128253.0
# ...                                                   ...          ...
# 9007ea08-91f4-4f7e-88bb-2028c6a83115                  0.0          2.0
# f94bf22a-875b-4e88-ad42-ffae18afde65                  0.0          1.0
# f62720f2-cdfe-4fa3-b54e-530f595e0007                  0.0         48.0
# 14f89ec0-bf3e-4168-ac3c-b9177edfbec6                  0.0          3.0
# d3c596c1-d404-4517-ab40-c127fc8b44a3                  0.0          1.0
#
# [153698 rows x 45 columns]

# %%
targeted_mask = (y_true_dos == 'Slowloris') & (pd.Series(y_predict) != 'Slowloris')
failed_idx = targeted_mask[targeted_mask].index
failed_idx
# Out:
# Index([ 1380,  1381,  1382,  1383,  1384,  1385,  1386,  1387,  1388,  1389,
#        ...
#         1811,  1812,  1817,  1818,  1827,  1829, 42029, 42036, 42037, 42040],
#       dtype='int64', length=342)

# %%
targeted_mask = (y_true_ps == 'PortScan')
portscan_idx = targeted_mask[targeted_mask].index
portscan_idx

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# X_failures contains instances your model gets wrong
pca = PCA(n_components=2)
pca.fit(X_train_fs)  # X_all is your complete dataset
# Out:
# PCA(n_components=2)

# %%
X_train_pca = pca.transform(X_train_fs)
X_test_pca = pca.transform(X_test_fs)

# %%
# Out:
# array(['Benign', 'Benign', 'Benign', ..., 'Benign', 'Benign', 'Benign'],
#       dtype='<U9')

# %%
targeted_mask = pd.Series(labelencoder.inverse_transform(y_train) == 'Slowloris')
train_dos_idx = targeted_mask[targeted_mask].index
train_dos_idx
# Out:
# Index([25316, 25317, 25318, 25319, 25320, 25321, 25322, 25323, 25324, 25325,
#        ...
#        87827, 87828, 87829, 87830, 87831, 87832, 87833, 87834, 87835, 87836],
#       dtype='int64', length=4565)

# %%
targeted_mask = pd.Series(labelencoder.inverse_transform(y_train) == 'Portscan')
train_ps_idx = targeted_mask[targeted_mask].index
train_ps_idx
# Out:
# Index([410578, 410579, 410581, 410582, 410584, 410588, 410592, 410593, 410596,
#        410601,
#        ...
#        594792, 594793, 594794, 594796, 594799, 594800, 594801, 594802, 594803,
#        594804],
#       dtype='int64', length=127232)

# %%
targeted_mask = (y_true_dos == 'Slowloris') & (pd.Series(y_predict) == 'Slowloris')
test_dos_success_idx = targeted_mask[targeted_mask].index
test_dos_success_idx
# Out:
# Index([  324,   338,   339,   342,   343,   350,   351,   367,   368,   372,
#        ...
#        41988, 41996, 42005, 42006, 42009, 42011, 42017, 42022, 42023, 42028],
#       dtype='int64', length=796)

# %%
targeted_mask = (y_true_dos == 'Slowloris') & (pd.Series(y_predict) != 'Slowloris')
test_dos_failed_idx = targeted_mask[targeted_mask].index
test_dos_failed_idx
# Out:
# Index([ 1380,  1381,  1382,  1383,  1384,  1385,  1386,  1387,  1388,  1389,
#        ...
#         1811,  1812,  1817,  1818,  1827,  1829, 42029, 42036, 42037, 42040],
#       dtype='int64', length=342)

# %%
targeted_mask = (y_true_dos == 'Slowloris')
test_dos_idx = targeted_mask[targeted_mask].index
test_dos_idx
# Out:
# Index([  324,   338,   339,   342,   343,   350,   351,   367,   368,   372,
#        ...
#        42009, 42011, 42017, 42022, 42023, 42028, 42029, 42036, 42037, 42040],
#       dtype='int64', length=1138)

# %%
targeted_mask = (y_true_ps == 'PortScan')
test_ps_idx = targeted_mask[targeted_mask].index
test_ps_idx
# Out:
# Index([ 36196,  36197,  36198,  36200,  36201,  36202,  36203,  36204,  36205,
#         36208,
#        ...
#         96259,  96260,  96265,  96266,  96267,  96268,  96383,  96384,  96395,
#        129835],
#       dtype='int64', length=31808)

# %%
len(X_train_pca[train_dos_idx])
# Out:
# 4565

# %%
plt.scatter(X_train_pca[train_dos_idx,0], X_train_pca[train_dos_idx,1], c='blue', alpha=0.1, label='Training Data')
plt.scatter(X_test_pca[test_dos_idx,0], X_test_pca[test_dos_idx,1], c='green', alpha=0.1, label='Test Data (Successfully Predicted)')
plt.scatter(X_test_pca[failed_idx,0], X_test_pca[failed_idx,1], c='red', alpha=0.1, label='Test Data (Failed Predict)')
plt.legend()
plt.title('PCA Visualization of Failure Cases')
# Out:
# Text(0.5, 1.0, 'PCA Visualization of Failure Cases')

# %%
from sklearn.manifold import TSNE

tsne = TSNE(n_components=2, perplexity=30, verbose=10)
X_tsne = tsne.fit_transform(X_train_fs)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 616981 samples in 0.081s...
# [t-SNE] Computed neighbors for 616981 samples in 177.943s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 616981
# [t-SNE] Computed conditional probabilities for sample 2000 / 616981
# [t-SNE] Computed conditional probabilities for sample 3000 / 616981
# [t-SNE] Computed conditional probabilities for sample 4000 / 616981
# [t-SNE] Computed conditional probabilities for sample 5000 / 616981
# [t-SNE] Computed conditional probabilities for sample 6000 / 616981
# [t-SNE] Computed conditional probabilities for sample 7000 / 616981
# [t-SNE] Computed conditional probabilities for sample 8000 / 616981
# [t-SNE] Computed conditional probabilities for sample 9000 / 616981
# [t-SNE] Computed conditional probabilities for sample 10000 / 616981
# [t-SNE] Computed conditional probabilities for sample 11000 / 616981
# [t-SNE] Computed conditional probabilities for sample 12000 / 616981
# [t-SNE] Computed conditional probabilities for sample 13000 / 616981
# [t-SNE] Computed conditional probabilities for sample 14000 / 616981
# [t-SNE] Computed conditional probabilities for sample 15000 / 616981
# [t-SNE] Computed conditional probabilities for sample 16000 / 616981
# [t-SNE] Computed conditional probabilities for sample 17000 / 616981
# [t-SNE] Computed conditional probabilities for sample 18000 / 616981
# [t-SNE] Computed conditional probabilities for sample 19000 / 616981
# [t-SNE] Computed conditional probabilities for sample 20000 / 616981
# [t-SNE] Computed conditional probabilities for sample 21000 / 616981
# [t-SNE] Computed conditional probabilities for sample 22000 / 616981
# [t-SNE] Computed conditional probabilities for sample 23000 / 616981
# [t-SNE] Computed conditional probabilities for sample 24000 / 616981
# [t-SNE] Computed conditional probabilities for sample 25000 / 616981
# [t-SNE] Computed conditional probabilities for sample 26000 / 616981
# [t-SNE] Computed conditional probabilities for sample 27000 / 616981
# [t-SNE] Computed conditional probabilities for sample 28000 / 616981
# [t-SNE] Computed conditional probabilities for sample 29000 / 616981
# [t-SNE] Computed conditional probabilities for sample 30000 / 616981
# [t-SNE] Computed conditional probabilities for sample 31000 / 616981
# [t-SNE] Computed conditional probabilities for sample 32000 / 616981
# [t-SNE] Computed conditional probabilities for sample 33000 / 616981
# [t-SNE] Computed conditional probabilities for sample 34000 / 616981
# [t-SNE] Computed conditional probabilities for sample 35000 / 616981
# [t-SNE] Computed conditional probabilities for sample 36000 / 616981
# [t-SNE] Computed conditional probabilities for sample 37000 / 616981
# [t-SNE] Computed conditional probabilities for sample 38000 / 616981
# [t-SNE] Computed conditional probabilities for sample 39000 / 616981
# [t-SNE] Computed conditional probabilities for sample 40000 / 616981
# [t-SNE] Computed conditional probabilities for sample 41000 / 616981
# [t-SNE] Computed conditional probabilities for sample 42000 / 616981
# [t-SNE] Computed conditional probabilities for sample 43000 / 616981
# [t-SNE] Computed conditional probabilities for sample 44000 / 616981
# [t-SNE] Computed conditional probabilities for sample 45000 / 616981
# [t-SNE] Computed conditional probabilities for sample 46000 / 616981
# [t-SNE] Computed conditional probabilities for sample 47000 / 616981
# [t-SNE] Computed conditional probabilities for sample 48000 / 616981
# [t-SNE] Computed conditional probabilities for sample 49000 / 616981
# [t-SNE] Computed conditional probabilities for sample 50000 / 616981
# [t-SNE] Computed conditional probabilities for sample 51000 / 616981
# [t-SNE] Computed conditional probabilities for sample 52000 / 616981
# [t-SNE] Computed conditional probabilities for sample 53000 / 616981
# [t-SNE] Computed conditional probabilities for sample 54000 / 616981
# [t-SNE] Computed conditional probabilities for sample 55000 / 616981
# [t-SNE] Computed conditional probabilities for sample 56000 / 616981
# [t-SNE] Computed conditional probabilities for sample 57000 / 616981
# [t-SNE] Computed conditional probabilities for sample 58000 / 616981
# [t-SNE] Computed conditional probabilities for sample 59000 / 616981
# [t-SNE] Computed conditional probabilities for sample 60000 / 616981
# [t-SNE] Computed conditional probabilities for sample 61000 / 616981
# [t-SNE] Computed conditional probabilities for sample 62000 / 616981
# [t-SNE] Computed conditional probabilities for sample 63000 / 616981
# [t-SNE] Computed conditional probabilities for sample 64000 / 616981
# [t-SNE] Computed conditional probabilities for sample 65000 / 616981
# [t-SNE] Computed conditional probabilities for sample 66000 / 616981
# [t-SNE] Computed conditional probabilities for sample 67000 / 616981
# [t-SNE] Computed conditional probabilities for sample 68000 / 616981
# [t-SNE] Computed conditional probabilities for sample 69000 / 616981
# [t-SNE] Computed conditional probabilities for sample 70000 / 616981
# [t-SNE] Computed conditional probabilities for sample 71000 / 616981
# [t-SNE] Computed conditional probabilities for sample 72000 / 616981
# [t-SNE] Computed conditional probabilities for sample 73000 / 616981
# [t-SNE] Computed conditional probabilities for sample 74000 / 616981
# [t-SNE] Computed conditional probabilities for sample 75000 / 616981
# [t-SNE] Computed conditional probabilities for sample 76000 / 616981
# [t-SNE] Computed conditional probabilities for sample 77000 / 616981
# [t-SNE] Computed conditional probabilities for sample 78000 / 616981
# [t-SNE] Computed conditional probabilities for sample 79000 / 616981
# [t-SNE] Computed conditional probabilities for sample 80000 / 616981
# [t-SNE] Computed conditional probabilities for sample 81000 / 616981
# [t-SNE] Computed conditional probabilities for sample 82000 / 616981
# [t-SNE] Computed conditional probabilities for sample 83000 / 616981
# [t-SNE] Computed conditional probabilities for sample 84000 / 616981
# [t-SNE] Computed conditional probabilities for sample 85000 / 616981
# [t-SNE] Computed conditional probabilities for sample 86000 / 616981
# [t-SNE] Computed conditional probabilities for sample 87000 / 616981
# [t-SNE] Computed conditional probabilities for sample 88000 / 616981
# [t-SNE] Computed conditional probabilities for sample 89000 / 616981
# [t-SNE] Computed conditional probabilities for sample 90000 / 616981
# [t-SNE] Computed conditional probabilities for sample 91000 / 616981
# [t-SNE] Computed conditional probabilities for sample 92000 / 616981
# [t-SNE] Computed conditional probabilities for sample 93000 / 616981
# [t-SNE] Computed conditional probabilities for sample 94000 / 616981
# [t-SNE] Computed conditional probabilities for sample 95000 / 616981
# [t-SNE] Computed conditional probabilities for sample 96000 / 616981
# [t-SNE] Computed conditional probabilities for sample 97000 / 616981
# [t-SNE] Computed conditional probabilities for sample 98000 / 616981
# [t-SNE] Computed conditional probabilities for sample 99000 / 616981
# [t-SNE] Computed conditional probabilities for sample 100000 / 616981
# [t-SNE] Computed conditional probabilities for sample 101000 / 616981
# [t-SNE] Computed conditional probabilities for sample 102000 / 616981
# [t-SNE] Computed conditional probabilities for sample 103000 / 616981
# [t-SNE] Computed conditional probabilities for sample 104000 / 616981
# [t-SNE] Computed conditional probabilities for sample 105000 / 616981
# [t-SNE] Computed conditional probabilities for sample 106000 / 616981
# [t-SNE] Computed conditional probabilities for sample 107000 / 616981
# [t-SNE] Computed conditional probabilities for sample 108000 / 616981
# [t-SNE] Computed conditional probabilities for sample 109000 / 616981
# [t-SNE] Computed conditional probabilities for sample 110000 / 616981
# [t-SNE] Computed conditional probabilities for sample 111000 / 616981
# [t-SNE] Computed conditional probabilities for sample 112000 / 616981
# [t-SNE] Computed conditional probabilities for sample 113000 / 616981
# [t-SNE] Computed conditional probabilities for sample 114000 / 616981
# [t-SNE] Computed conditional probabilities for sample 115000 / 616981
# [t-SNE] Computed conditional probabilities for sample 116000 / 616981
# [t-SNE] Computed conditional probabilities for sample 117000 / 616981
# [t-SNE] Computed conditional probabilities for sample 118000 / 616981
# [t-SNE] Computed conditional probabilities for sample 119000 / 616981
# [t-SNE] Computed conditional probabilities for sample 120000 / 616981
# [t-SNE] Computed conditional probabilities for sample 121000 / 616981
# [t-SNE] Computed conditional probabilities for sample 122000 / 616981
# [t-SNE] Computed conditional probabilities for sample 123000 / 616981
# [t-SNE] Computed conditional probabilities for sample 124000 / 616981
# [t-SNE] Computed conditional probabilities for sample 125000 / 616981
# [t-SNE] Computed conditional probabilities for sample 126000 / 616981
# [t-SNE] Computed conditional probabilities for sample 127000 / 616981
# [t-SNE] Computed conditional probabilities for sample 128000 / 616981
# [t-SNE] Computed conditional probabilities for sample 129000 / 616981
# [t-SNE] Computed conditional probabilities for sample 130000 / 616981
# [t-SNE] Computed conditional probabilities for sample 131000 / 616981
# [t-SNE] Computed conditional probabilities for sample 132000 / 616981
# [t-SNE] Computed conditional probabilities for sample 133000 / 616981
# [t-SNE] Computed conditional probabilities for sample 134000 / 616981
# [t-SNE] Computed conditional probabilities for sample 135000 / 616981
# [t-SNE] Computed conditional probabilities for sample 136000 / 616981
# [t-SNE] Computed conditional probabilities for sample 137000 / 616981
# [t-SNE] Computed conditional probabilities for sample 138000 / 616981
# [t-SNE] Computed conditional probabilities for sample 139000 / 616981
# [t-SNE] Computed conditional probabilities for sample 140000 / 616981
# [t-SNE] Computed conditional probabilities for sample 141000 / 616981
# [t-SNE] Computed conditional probabilities for sample 142000 / 616981
# [t-SNE] Computed conditional probabilities for sample 143000 / 616981
# [t-SNE] Computed conditional probabilities for sample 144000 / 616981
# [t-SNE] Computed conditional probabilities for sample 145000 / 616981
# [t-SNE] Computed conditional probabilities for sample 146000 / 616981
# [t-SNE] Computed conditional probabilities for sample 147000 / 616981
# [t-SNE] Computed conditional probabilities for sample 148000 / 616981
# [t-SNE] Computed conditional probabilities for sample 149000 / 616981
# [t-SNE] Computed conditional probabilities for sample 150000 / 616981
# [t-SNE] Computed conditional probabilities for sample 151000 / 616981
# [t-SNE] Computed conditional probabilities for sample 152000 / 616981
# [t-SNE] Computed conditional probabilities for sample 153000 / 616981
# [t-SNE] Computed conditional probabilities for sample 154000 / 616981
# [t-SNE] Computed conditional probabilities for sample 155000 / 616981
# [t-SNE] Computed conditional probabilities for sample 156000 / 616981
# [t-SNE] Computed conditional probabilities for sample 157000 / 616981
# [t-SNE] Computed conditional probabilities for sample 158000 / 616981
# [t-SNE] Computed conditional probabilities for sample 159000 / 616981
# [t-SNE] Computed conditional probabilities for sample 160000 / 616981
# [t-SNE] Computed conditional probabilities for sample 161000 / 616981
# [t-SNE] Computed conditional probabilities for sample 162000 / 616981
# [t-SNE] Computed conditional probabilities for sample 163000 / 616981
# [t-SNE] Computed conditional probabilities for sample 164000 / 616981
# [t-SNE] Computed conditional probabilities for sample 165000 / 616981
# [t-SNE] Computed conditional probabilities for sample 166000 / 616981
# [t-SNE] Computed conditional probabilities for sample 167000 / 616981
# [t-SNE] Computed conditional probabilities for sample 168000 / 616981
# [t-SNE] Computed conditional probabilities for sample 169000 / 616981
# [t-SNE] Computed conditional probabilities for sample 170000 / 616981
# [t-SNE] Computed conditional probabilities for sample 171000 / 616981
# [t-SNE] Computed conditional probabilities for sample 172000 / 616981
# [t-SNE] Computed conditional probabilities for sample 173000 / 616981
# [t-SNE] Computed conditional probabilities for sample 174000 / 616981
# [t-SNE] Computed conditional probabilities for sample 175000 / 616981
# [t-SNE] Computed conditional probabilities for sample 176000 / 616981
# [t-SNE] Computed conditional probabilities for sample 177000 / 616981
# [t-SNE] Computed conditional probabilities for sample 178000 / 616981
# [t-SNE] Computed conditional probabilities for sample 179000 / 616981
# [t-SNE] Computed conditional probabilities for sample 180000 / 616981
# [t-SNE] Computed conditional probabilities for sample 181000 / 616981
# [t-SNE] Computed conditional probabilities for sample 182000 / 616981
# [t-SNE] Computed conditional probabilities for sample 183000 / 616981
# [t-SNE] Computed conditional probabilities for sample 184000 / 616981
# [t-SNE] Computed conditional probabilities for sample 185000 / 616981
# [t-SNE] Computed conditional probabilities for sample 186000 / 616981
# [t-SNE] Computed conditional probabilities for sample 187000 / 616981
# [t-SNE] Computed conditional probabilities for sample 188000 / 616981
# [t-SNE] Computed conditional probabilities for sample 189000 / 616981
# [t-SNE] Computed conditional probabilities for sample 190000 / 616981
# [t-SNE] Computed conditional probabilities for sample 191000 / 616981
# [t-SNE] Computed conditional probabilities for sample 192000 / 616981
# [t-SNE] Computed conditional probabilities for sample 193000 / 616981
# [t-SNE] Computed conditional probabilities for sample 194000 / 616981
# [t-SNE] Computed conditional probabilities for sample 195000 / 616981
# [t-SNE] Computed conditional probabilities for sample 196000 / 616981
# [t-SNE] Computed conditional probabilities for sample 197000 / 616981
# [t-SNE] Computed conditional probabilities for sample 198000 / 616981
# [t-SNE] Computed conditional probabilities for sample 199000 / 616981
# [t-SNE] Computed conditional probabilities for sample 200000 / 616981
# [t-SNE] Computed conditional probabilities for sample 201000 / 616981
# [t-SNE] Computed conditional probabilities for sample 202000 / 616981
# [t-SNE] Computed conditional probabilities for sample 203000 / 616981
# [t-SNE] Computed conditional probabilities for sample 204000 / 616981
# [t-SNE] Computed conditional probabilities for sample 205000 / 616981
# [t-SNE] Computed conditional probabilities for sample 206000 / 616981
# [t-SNE] Computed conditional probabilities for sample 207000 / 616981
# [t-SNE] Computed conditional probabilities for sample 208000 / 616981
# [t-SNE] Computed conditional probabilities for sample 209000 / 616981
# [t-SNE] Computed conditional probabilities for sample 210000 / 616981
# [t-SNE] Computed conditional probabilities for sample 211000 / 616981
# [t-SNE] Computed conditional probabilities for sample 212000 / 616981
# [t-SNE] Computed conditional probabilities for sample 213000 / 616981
# [t-SNE] Computed conditional probabilities for sample 214000 / 616981
# [t-SNE] Computed conditional probabilities for sample 215000 / 616981
# [t-SNE] Computed conditional probabilities for sample 216000 / 616981
# [t-SNE] Computed conditional probabilities for sample 217000 / 616981
# [t-SNE] Computed conditional probabilities for sample 218000 / 616981
# [t-SNE] Computed conditional probabilities for sample 219000 / 616981
# [t-SNE] Computed conditional probabilities for sample 220000 / 616981
# [t-SNE] Computed conditional probabilities for sample 221000 / 616981
# [t-SNE] Computed conditional probabilities for sample 222000 / 616981
# [t-SNE] Computed conditional probabilities for sample 223000 / 616981
# [t-SNE] Computed conditional probabilities for sample 224000 / 616981
# [t-SNE] Computed conditional probabilities for sample 225000 / 616981
# [t-SNE] Computed conditional probabilities for sample 226000 / 616981
# [t-SNE] Computed conditional probabilities for sample 227000 / 616981
# [t-SNE] Computed conditional probabilities for sample 228000 / 616981
# [t-SNE] Computed conditional probabilities for sample 229000 / 616981
# [t-SNE] Computed conditional probabilities for sample 230000 / 616981
# [t-SNE] Computed conditional probabilities for sample 231000 / 616981
# [t-SNE] Computed conditional probabilities for sample 232000 / 616981
# [t-SNE] Computed conditional probabilities for sample 233000 / 616981
# [t-SNE] Computed conditional probabilities for sample 234000 / 616981
# [t-SNE] Computed conditional probabilities for sample 235000 / 616981
# [t-SNE] Computed conditional probabilities for sample 236000 / 616981
# [t-SNE] Computed conditional probabilities for sample 237000 / 616981
# [t-SNE] Computed conditional probabilities for sample 238000 / 616981
# [t-SNE] Computed conditional probabilities for sample 239000 / 616981
# [t-SNE] Computed conditional probabilities for sample 240000 / 616981
# [t-SNE] Computed conditional probabilities for sample 241000 / 616981
# [t-SNE] Computed conditional probabilities for sample 242000 / 616981
# [t-SNE] Computed conditional probabilities for sample 243000 / 616981
# [t-SNE] Computed conditional probabilities for sample 244000 / 616981
# [t-SNE] Computed conditional probabilities for sample 245000 / 616981
# [t-SNE] Computed conditional probabilities for sample 246000 / 616981
# [t-SNE] Computed conditional probabilities for sample 247000 / 616981
# [t-SNE] Computed conditional probabilities for sample 248000 / 616981
# [t-SNE] Computed conditional probabilities for sample 249000 / 616981
# [t-SNE] Computed conditional probabilities for sample 250000 / 616981
# [t-SNE] Computed conditional probabilities for sample 251000 / 616981
# [t-SNE] Computed conditional probabilities for sample 252000 / 616981
# [t-SNE] Computed conditional probabilities for sample 253000 / 616981
# [t-SNE] Computed conditional probabilities for sample 254000 / 616981
# [t-SNE] Computed conditional probabilities for sample 255000 / 616981
# [t-SNE] Computed conditional probabilities for sample 256000 / 616981
# [t-SNE] Computed conditional probabilities for sample 257000 / 616981
# [t-SNE] Computed conditional probabilities for sample 258000 / 616981
# [t-SNE] Computed conditional probabilities for sample 259000 / 616981
# [t-SNE] Computed conditional probabilities for sample 260000 / 616981
# [t-SNE] Computed conditional probabilities for sample 261000 / 616981
# [t-SNE] Computed conditional probabilities for sample 262000 / 616981
# [t-SNE] Computed conditional probabilities for sample 263000 / 616981
# [t-SNE] Computed conditional probabilities for sample 264000 / 616981
# [t-SNE] Computed conditional probabilities for sample 265000 / 616981
# [t-SNE] Computed conditional probabilities for sample 266000 / 616981
# [t-SNE] Computed conditional probabilities for sample 267000 / 616981
# [t-SNE] Computed conditional probabilities for sample 268000 / 616981
# [t-SNE] Computed conditional probabilities for sample 269000 / 616981
# [t-SNE] Computed conditional probabilities for sample 270000 / 616981
# [t-SNE] Computed conditional probabilities for sample 271000 / 616981
# [t-SNE] Computed conditional probabilities for sample 272000 / 616981
# [t-SNE] Computed conditional probabilities for sample 273000 / 616981
# [t-SNE] Computed conditional probabilities for sample 274000 / 616981
# [t-SNE] Computed conditional probabilities for sample 275000 / 616981
# [t-SNE] Computed conditional probabilities for sample 276000 / 616981
# [t-SNE] Computed conditional probabilities for sample 277000 / 616981
# [t-SNE] Computed conditional probabilities for sample 278000 / 616981
# [t-SNE] Computed conditional probabilities for sample 279000 / 616981
# [t-SNE] Computed conditional probabilities for sample 280000 / 616981
# [t-SNE] Computed conditional probabilities for sample 281000 / 616981
# [t-SNE] Computed conditional probabilities for sample 282000 / 616981
# [t-SNE] Computed conditional probabilities for sample 283000 / 616981
# [t-SNE] Computed conditional probabilities for sample 284000 / 616981
# [t-SNE] Computed conditional probabilities for sample 285000 / 616981
# [t-SNE] Computed conditional probabilities for sample 286000 / 616981
# [t-SNE] Computed conditional probabilities for sample 287000 / 616981
# [t-SNE] Computed conditional probabilities for sample 288000 / 616981
# [t-SNE] Computed conditional probabilities for sample 289000 / 616981
# [t-SNE] Computed conditional probabilities for sample 290000 / 616981
# [t-SNE] Computed conditional probabilities for sample 291000 / 616981
# [t-SNE] Computed conditional probabilities for sample 292000 / 616981
# [t-SNE] Computed conditional probabilities for sample 293000 / 616981
# [t-SNE] Computed conditional probabilities for sample 294000 / 616981
# [t-SNE] Computed conditional probabilities for sample 295000 / 616981
# [t-SNE] Computed conditional probabilities for sample 296000 / 616981
# [t-SNE] Computed conditional probabilities for sample 297000 / 616981
# [t-SNE] Computed conditional probabilities for sample 298000 / 616981
# [t-SNE] Computed conditional probabilities for sample 299000 / 616981
# [t-SNE] Computed conditional probabilities for sample 300000 / 616981
# [t-SNE] Computed conditional probabilities for sample 301000 / 616981
# [t-SNE] Computed conditional probabilities for sample 302000 / 616981
# [t-SNE] Computed conditional probabilities for sample 303000 / 616981
# [t-SNE] Computed conditional probabilities for sample 304000 / 616981
# [t-SNE] Computed conditional probabilities for sample 305000 / 616981
# [t-SNE] Computed conditional probabilities for sample 306000 / 616981
# [t-SNE] Computed conditional probabilities for sample 307000 / 616981
# [t-SNE] Computed conditional probabilities for sample 308000 / 616981
# [t-SNE] Computed conditional probabilities for sample 309000 / 616981
# [t-SNE] Computed conditional probabilities for sample 310000 / 616981
# [t-SNE] Computed conditional probabilities for sample 311000 / 616981
# [t-SNE] Computed conditional probabilities for sample 312000 / 616981
# [t-SNE] Computed conditional probabilities for sample 313000 / 616981
# [t-SNE] Computed conditional probabilities for sample 314000 / 616981
# [t-SNE] Computed conditional probabilities for sample 315000 / 616981
# [t-SNE] Computed conditional probabilities for sample 316000 / 616981
# [t-SNE] Computed conditional probabilities for sample 317000 / 616981
# [t-SNE] Computed conditional probabilities for sample 318000 / 616981
# [t-SNE] Computed conditional probabilities for sample 319000 / 616981
# [t-SNE] Computed conditional probabilities for sample 320000 / 616981
# [t-SNE] Computed conditional probabilities for sample 321000 / 616981
# [t-SNE] Computed conditional probabilities for sample 322000 / 616981
# [t-SNE] Computed conditional probabilities for sample 323000 / 616981
# [t-SNE] Computed conditional probabilities for sample 324000 / 616981
# [t-SNE] Computed conditional probabilities for sample 325000 / 616981
# [t-SNE] Computed conditional probabilities for sample 326000 / 616981
# [t-SNE] Computed conditional probabilities for sample 327000 / 616981
# [t-SNE] Computed conditional probabilities for sample 328000 / 616981
# [t-SNE] Computed conditional probabilities for sample 329000 / 616981
# [t-SNE] Computed conditional probabilities for sample 330000 / 616981
# [t-SNE] Computed conditional probabilities for sample 331000 / 616981
# [t-SNE] Computed conditional probabilities for sample 332000 / 616981
# [t-SNE] Computed conditional probabilities for sample 333000 / 616981
# [t-SNE] Computed conditional probabilities for sample 334000 / 616981
# [t-SNE] Computed conditional probabilities for sample 335000 / 616981
# [t-SNE] Computed conditional probabilities for sample 336000 / 616981
# [t-SNE] Computed conditional probabilities for sample 337000 / 616981
# [t-SNE] Computed conditional probabilities for sample 338000 / 616981
# [t-SNE] Computed conditional probabilities for sample 339000 / 616981
# [t-SNE] Computed conditional probabilities for sample 340000 / 616981
# [t-SNE] Computed conditional probabilities for sample 341000 / 616981
# [t-SNE] Computed conditional probabilities for sample 342000 / 616981
# [t-SNE] Computed conditional probabilities for sample 343000 / 616981
# [t-SNE] Computed conditional probabilities for sample 344000 / 616981
# [t-SNE] Computed conditional probabilities for sample 345000 / 616981
# [t-SNE] Computed conditional probabilities for sample 346000 / 616981
# [t-SNE] Computed conditional probabilities for sample 347000 / 616981
# [t-SNE] Computed conditional probabilities for sample 348000 / 616981
# [t-SNE] Computed conditional probabilities for sample 349000 / 616981
# [t-SNE] Computed conditional probabilities for sample 350000 / 616981
# [t-SNE] Computed conditional probabilities for sample 351000 / 616981
# [t-SNE] Computed conditional probabilities for sample 352000 / 616981
# [t-SNE] Computed conditional probabilities for sample 353000 / 616981
# [t-SNE] Computed conditional probabilities for sample 354000 / 616981
# [t-SNE] Computed conditional probabilities for sample 355000 / 616981
# [t-SNE] Computed conditional probabilities for sample 356000 / 616981
# [t-SNE] Computed conditional probabilities for sample 357000 / 616981
# [t-SNE] Computed conditional probabilities for sample 358000 / 616981
# [t-SNE] Computed conditional probabilities for sample 359000 / 616981
# [t-SNE] Computed conditional probabilities for sample 360000 / 616981
# [t-SNE] Computed conditional probabilities for sample 361000 / 616981
# [t-SNE] Computed conditional probabilities for sample 362000 / 616981
# [t-SNE] Computed conditional probabilities for sample 363000 / 616981
# [t-SNE] Computed conditional probabilities for sample 364000 / 616981
# [t-SNE] Computed conditional probabilities for sample 365000 / 616981
# [t-SNE] Computed conditional probabilities for sample 366000 / 616981
# [t-SNE] Computed conditional probabilities for sample 367000 / 616981
# [t-SNE] Computed conditional probabilities for sample 368000 / 616981
# [t-SNE] Computed conditional probabilities for sample 369000 / 616981
# [t-SNE] Computed conditional probabilities for sample 370000 / 616981
# [t-SNE] Computed conditional probabilities for sample 371000 / 616981
# [t-SNE] Computed conditional probabilities for sample 372000 / 616981
# [t-SNE] Computed conditional probabilities for sample 373000 / 616981
# [t-SNE] Computed conditional probabilities for sample 374000 / 616981
# [t-SNE] Computed conditional probabilities for sample 375000 / 616981
# [t-SNE] Computed conditional probabilities for sample 376000 / 616981
# [t-SNE] Computed conditional probabilities for sample 377000 / 616981
# [t-SNE] Computed conditional probabilities for sample 378000 / 616981
# [t-SNE] Computed conditional probabilities for sample 379000 / 616981
# [t-SNE] Computed conditional probabilities for sample 380000 / 616981
# [t-SNE] Computed conditional probabilities for sample 381000 / 616981
# [t-SNE] Computed conditional probabilities for sample 382000 / 616981
# [t-SNE] Computed conditional probabilities for sample 383000 / 616981
# [t-SNE] Computed conditional probabilities for sample 384000 / 616981
# [t-SNE] Computed conditional probabilities for sample 385000 / 616981
# [t-SNE] Computed conditional probabilities for sample 386000 / 616981
# [t-SNE] Computed conditional probabilities for sample 387000 / 616981
# [t-SNE] Computed conditional probabilities for sample 388000 / 616981
# [t-SNE] Computed conditional probabilities for sample 389000 / 616981
# [t-SNE] Computed conditional probabilities for sample 390000 / 616981
# [t-SNE] Computed conditional probabilities for sample 391000 / 616981
# [t-SNE] Computed conditional probabilities for sample 392000 / 616981
# [t-SNE] Computed conditional probabilities for sample 393000 / 616981
# [t-SNE] Computed conditional probabilities for sample 394000 / 616981
# [t-SNE] Computed conditional probabilities for sample 395000 / 616981
# [t-SNE] Computed conditional probabilities for sample 396000 / 616981
# [t-SNE] Computed conditional probabilities for sample 397000 / 616981
# [t-SNE] Computed conditional probabilities for sample 398000 / 616981
# [t-SNE] Computed conditional probabilities for sample 399000 / 616981
# [t-SNE] Computed conditional probabilities for sample 400000 / 616981
# [t-SNE] Computed conditional probabilities for sample 401000 / 616981
# [t-SNE] Computed conditional probabilities for sample 402000 / 616981
# [t-SNE] Computed conditional probabilities for sample 403000 / 616981
# [t-SNE] Computed conditional probabilities for sample 404000 / 616981
# [t-SNE] Computed conditional probabilities for sample 405000 / 616981
# [t-SNE] Computed conditional probabilities for sample 406000 / 616981
# [t-SNE] Computed conditional probabilities for sample 407000 / 616981
# [t-SNE] Computed conditional probabilities for sample 408000 / 616981
# [t-SNE] Computed conditional probabilities for sample 409000 / 616981
# [t-SNE] Computed conditional probabilities for sample 410000 / 616981
# [t-SNE] Computed conditional probabilities for sample 411000 / 616981
# [t-SNE] Computed conditional probabilities for sample 412000 / 616981
# [t-SNE] Computed conditional probabilities for sample 413000 / 616981
# [t-SNE] Computed conditional probabilities for sample 414000 / 616981
# [t-SNE] Computed conditional probabilities for sample 415000 / 616981
# [t-SNE] Computed conditional probabilities for sample 416000 / 616981
# [t-SNE] Computed conditional probabilities for sample 417000 / 616981
# [t-SNE] Computed conditional probabilities for sample 418000 / 616981
# [t-SNE] Computed conditional probabilities for sample 419000 / 616981
# [t-SNE] Computed conditional probabilities for sample 420000 / 616981
# [t-SNE] Computed conditional probabilities for sample 421000 / 616981
# [t-SNE] Computed conditional probabilities for sample 422000 / 616981
# [t-SNE] Computed conditional probabilities for sample 423000 / 616981
# [t-SNE] Computed conditional probabilities for sample 424000 / 616981
# [t-SNE] Computed conditional probabilities for sample 425000 / 616981
# [t-SNE] Computed conditional probabilities for sample 426000 / 616981
# [t-SNE] Computed conditional probabilities for sample 427000 / 616981
# [t-SNE] Computed conditional probabilities for sample 428000 / 616981
# [t-SNE] Computed conditional probabilities for sample 429000 / 616981
# [t-SNE] Computed conditional probabilities for sample 430000 / 616981
# [t-SNE] Computed conditional probabilities for sample 431000 / 616981
# [t-SNE] Computed conditional probabilities for sample 432000 / 616981
# [t-SNE] Computed conditional probabilities for sample 433000 / 616981
# [t-SNE] Computed conditional probabilities for sample 434000 / 616981
# [t-SNE] Computed conditional probabilities for sample 435000 / 616981
# [t-SNE] Computed conditional probabilities for sample 436000 / 616981
# [t-SNE] Computed conditional probabilities for sample 437000 / 616981
# [t-SNE] Computed conditional probabilities for sample 438000 / 616981
# [t-SNE] Computed conditional probabilities for sample 439000 / 616981
# [t-SNE] Computed conditional probabilities for sample 440000 / 616981
# [t-SNE] Computed conditional probabilities for sample 441000 / 616981
# [t-SNE] Computed conditional probabilities for sample 442000 / 616981
# [t-SNE] Computed conditional probabilities for sample 443000 / 616981
# [t-SNE] Computed conditional probabilities for sample 444000 / 616981
# [t-SNE] Computed conditional probabilities for sample 445000 / 616981
# [t-SNE] Computed conditional probabilities for sample 446000 / 616981
# [t-SNE] Computed conditional probabilities for sample 447000 / 616981
# [t-SNE] Computed conditional probabilities for sample 448000 / 616981
# [t-SNE] Computed conditional probabilities for sample 449000 / 616981
# [t-SNE] Computed conditional probabilities for sample 450000 / 616981
# [t-SNE] Computed conditional probabilities for sample 451000 / 616981
# [t-SNE] Computed conditional probabilities for sample 452000 / 616981
# [t-SNE] Computed conditional probabilities for sample 453000 / 616981
# [t-SNE] Computed conditional probabilities for sample 454000 / 616981
# [t-SNE] Computed conditional probabilities for sample 455000 / 616981
# [t-SNE] Computed conditional probabilities for sample 456000 / 616981
# [t-SNE] Computed conditional probabilities for sample 457000 / 616981
# [t-SNE] Computed conditional probabilities for sample 458000 / 616981
# [t-SNE] Computed conditional probabilities for sample 459000 / 616981
# [t-SNE] Computed conditional probabilities for sample 460000 / 616981
# [t-SNE] Computed conditional probabilities for sample 461000 / 616981
# [t-SNE] Computed conditional probabilities for sample 462000 / 616981
# [t-SNE] Computed conditional probabilities for sample 463000 / 616981
# [t-SNE] Computed conditional probabilities for sample 464000 / 616981
# [t-SNE] Computed conditional probabilities for sample 465000 / 616981
# [t-SNE] Computed conditional probabilities for sample 466000 / 616981
# [t-SNE] Computed conditional probabilities for sample 467000 / 616981
# [t-SNE] Computed conditional probabilities for sample 468000 / 616981
# [t-SNE] Computed conditional probabilities for sample 469000 / 616981
# [t-SNE] Computed conditional probabilities for sample 470000 / 616981
# [t-SNE] Computed conditional probabilities for sample 471000 / 616981
# [t-SNE] Computed conditional probabilities for sample 472000 / 616981
# [t-SNE] Computed conditional probabilities for sample 473000 / 616981
# [t-SNE] Computed conditional probabilities for sample 474000 / 616981
# [t-SNE] Computed conditional probabilities for sample 475000 / 616981
# [t-SNE] Computed conditional probabilities for sample 476000 / 616981
# [t-SNE] Computed conditional probabilities for sample 477000 / 616981
# [t-SNE] Computed conditional probabilities for sample 478000 / 616981
# [t-SNE] Computed conditional probabilities for sample 479000 / 616981
# [t-SNE] Computed conditional probabilities for sample 480000 / 616981
# [t-SNE] Computed conditional probabilities for sample 481000 / 616981
# [t-SNE] Computed conditional probabilities for sample 482000 / 616981
# [t-SNE] Computed conditional probabilities for sample 483000 / 616981
# [t-SNE] Computed conditional probabilities for sample 484000 / 616981
# [t-SNE] Computed conditional probabilities for sample 485000 / 616981
# [t-SNE] Computed conditional probabilities for sample 486000 / 616981
# [t-SNE] Computed conditional probabilities for sample 487000 / 616981
# [t-SNE] Computed conditional probabilities for sample 488000 / 616981
# [t-SNE] Computed conditional probabilities for sample 489000 / 616981
# [t-SNE] Computed conditional probabilities for sample 490000 / 616981
# [t-SNE] Computed conditional probabilities for sample 491000 / 616981
# [t-SNE] Computed conditional probabilities for sample 492000 / 616981
# [t-SNE] Computed conditional probabilities for sample 493000 / 616981
# [t-SNE] Computed conditional probabilities for sample 494000 / 616981
# [t-SNE] Computed conditional probabilities for sample 495000 / 616981
# [t-SNE] Computed conditional probabilities for sample 496000 / 616981
# [t-SNE] Computed conditional probabilities for sample 497000 / 616981
# [t-SNE] Computed conditional probabilities for sample 498000 / 616981
# [t-SNE] Computed conditional probabilities for sample 499000 / 616981
# [t-SNE] Computed conditional probabilities for sample 500000 / 616981
# [t-SNE] Computed conditional probabilities for sample 501000 / 616981
# [t-SNE] Computed conditional probabilities for sample 502000 / 616981
# [t-SNE] Computed conditional probabilities for sample 503000 / 616981
# [t-SNE] Computed conditional probabilities for sample 504000 / 616981
# [t-SNE] Computed conditional probabilities for sample 505000 / 616981
# [t-SNE] Computed conditional probabilities for sample 506000 / 616981
# [t-SNE] Computed conditional probabilities for sample 507000 / 616981
# [t-SNE] Computed conditional probabilities for sample 508000 / 616981
# [t-SNE] Computed conditional probabilities for sample 509000 / 616981
# [t-SNE] Computed conditional probabilities for sample 510000 / 616981
# [t-SNE] Computed conditional probabilities for sample 511000 / 616981
# [t-SNE] Computed conditional probabilities for sample 512000 / 616981
# [t-SNE] Computed conditional probabilities for sample 513000 / 616981
# [t-SNE] Computed conditional probabilities for sample 514000 / 616981
# [t-SNE] Computed conditional probabilities for sample 515000 / 616981
# [t-SNE] Computed conditional probabilities for sample 516000 / 616981
# [t-SNE] Computed conditional probabilities for sample 517000 / 616981
# [t-SNE] Computed conditional probabilities for sample 518000 / 616981
# [t-SNE] Computed conditional probabilities for sample 519000 / 616981
# [t-SNE] Computed conditional probabilities for sample 520000 / 616981
# [t-SNE] Computed conditional probabilities for sample 521000 / 616981
# [t-SNE] Computed conditional probabilities for sample 522000 / 616981
# [t-SNE] Computed conditional probabilities for sample 523000 / 616981
# [t-SNE] Computed conditional probabilities for sample 524000 / 616981
# [t-SNE] Computed conditional probabilities for sample 525000 / 616981
# [t-SNE] Computed conditional probabilities for sample 526000 / 616981
# [t-SNE] Computed conditional probabilities for sample 527000 / 616981
# [t-SNE] Computed conditional probabilities for sample 528000 / 616981
# [t-SNE] Computed conditional probabilities for sample 529000 / 616981
# [t-SNE] Computed conditional probabilities for sample 530000 / 616981
# [t-SNE] Computed conditional probabilities for sample 531000 / 616981
# [t-SNE] Computed conditional probabilities for sample 532000 / 616981
# [t-SNE] Computed conditional probabilities for sample 533000 / 616981
# [t-SNE] Computed conditional probabilities for sample 534000 / 616981
# [t-SNE] Computed conditional probabilities for sample 535000 / 616981
# [t-SNE] Computed conditional probabilities for sample 536000 / 616981
# [t-SNE] Computed conditional probabilities for sample 537000 / 616981
# [t-SNE] Computed conditional probabilities for sample 538000 / 616981
# [t-SNE] Computed conditional probabilities for sample 539000 / 616981
# [t-SNE] Computed conditional probabilities for sample 540000 / 616981
# [t-SNE] Computed conditional probabilities for sample 541000 / 616981
# [t-SNE] Computed conditional probabilities for sample 542000 / 616981
# [t-SNE] Computed conditional probabilities for sample 543000 / 616981
# [t-SNE] Computed conditional probabilities for sample 544000 / 616981
# [t-SNE] Computed conditional probabilities for sample 545000 / 616981
# [t-SNE] Computed conditional probabilities for sample 546000 / 616981
# [t-SNE] Computed conditional probabilities for sample 547000 / 616981
# [t-SNE] Computed conditional probabilities for sample 548000 / 616981
# [t-SNE] Computed conditional probabilities for sample 549000 / 616981
# [t-SNE] Computed conditional probabilities for sample 550000 / 616981
# [t-SNE] Computed conditional probabilities for sample 551000 / 616981
# [t-SNE] Computed conditional probabilities for sample 552000 / 616981
# [t-SNE] Computed conditional probabilities for sample 553000 / 616981
# [t-SNE] Computed conditional probabilities for sample 554000 / 616981
# [t-SNE] Computed conditional probabilities for sample 555000 / 616981
# [t-SNE] Computed conditional probabilities for sample 556000 / 616981
# [t-SNE] Computed conditional probabilities for sample 557000 / 616981
# [t-SNE] Computed conditional probabilities for sample 558000 / 616981
# [t-SNE] Computed conditional probabilities for sample 559000 / 616981
# [t-SNE] Computed conditional probabilities for sample 560000 / 616981
# [t-SNE] Computed conditional probabilities for sample 561000 / 616981
# [t-SNE] Computed conditional probabilities for sample 562000 / 616981
# [t-SNE] Computed conditional probabilities for sample 563000 / 616981
# [t-SNE] Computed conditional probabilities for sample 564000 / 616981
# [t-SNE] Computed conditional probabilities for sample 565000 / 616981
# [t-SNE] Computed conditional probabilities for sample 566000 / 616981
# [t-SNE] Computed conditional probabilities for sample 567000 / 616981
# [t-SNE] Computed conditional probabilities for sample 568000 / 616981
# [t-SNE] Computed conditional probabilities for sample 569000 / 616981
# [t-SNE] Computed conditional probabilities for sample 570000 / 616981
# [t-SNE] Computed conditional probabilities for sample 571000 / 616981
# [t-SNE] Computed conditional probabilities for sample 572000 / 616981
# [t-SNE] Computed conditional probabilities for sample 573000 / 616981
# [t-SNE] Computed conditional probabilities for sample 574000 / 616981
# [t-SNE] Computed conditional probabilities for sample 575000 / 616981
# [t-SNE] Computed conditional probabilities for sample 576000 / 616981
# [t-SNE] Computed conditional probabilities for sample 577000 / 616981
# [t-SNE] Computed conditional probabilities for sample 578000 / 616981
# [t-SNE] Computed conditional probabilities for sample 579000 / 616981
# [t-SNE] Computed conditional probabilities for sample 580000 / 616981
# [t-SNE] Computed conditional probabilities for sample 581000 / 616981
# [t-SNE] Computed conditional probabilities for sample 582000 / 616981
# [t-SNE] Computed conditional probabilities for sample 583000 / 616981
# [t-SNE] Computed conditional probabilities for sample 584000 / 616981
# [t-SNE] Computed conditional probabilities for sample 585000 / 616981
# [t-SNE] Computed conditional probabilities for sample 586000 / 616981
# [t-SNE] Computed conditional probabilities for sample 587000 / 616981
# [t-SNE] Computed conditional probabilities for sample 588000 / 616981
# [t-SNE] Computed conditional probabilities for sample 589000 / 616981
# [t-SNE] Computed conditional probabilities for sample 590000 / 616981
# [t-SNE] Computed conditional probabilities for sample 591000 / 616981
# [t-SNE] Computed conditional probabilities for sample 592000 / 616981
# [t-SNE] Computed conditional probabilities for sample 593000 / 616981
# [t-SNE] Computed conditional probabilities for sample 594000 / 616981
# [t-SNE] Computed conditional probabilities for sample 595000 / 616981
# [t-SNE] Computed conditional probabilities for sample 596000 / 616981
# [t-SNE] Computed conditional probabilities for sample 597000 / 616981
# [t-SNE] Computed conditional probabilities for sample 598000 / 616981
# [t-SNE] Computed conditional probabilities for sample 599000 / 616981
# [t-SNE] Computed conditional probabilities for sample 600000 / 616981
# [t-SNE] Computed conditional probabilities for sample 601000 / 616981
# [t-SNE] Computed conditional probabilities for sample 602000 / 616981
# [t-SNE] Computed conditional probabilities for sample 603000 / 616981
# [t-SNE] Computed conditional probabilities for sample 604000 / 616981
# [t-SNE] Computed conditional probabilities for sample 605000 / 616981
# [t-SNE] Computed conditional probabilities for sample 606000 / 616981
# [t-SNE] Computed conditional probabilities for sample 607000 / 616981
# [t-SNE] Computed conditional probabilities for sample 608000 / 616981
# [t-SNE] Computed conditional probabilities for sample 609000 / 616981
# [t-SNE] Computed conditional probabilities for sample 610000 / 616981
# [t-SNE] Computed conditional probabilities for sample 611000 / 616981
# [t-SNE] Computed conditional probabilities for sample 612000 / 616981
# [t-SNE] Computed conditional probabilities for sample 613000 / 616981
# [t-SNE] Computed conditional probabilities for sample 614000 / 616981
# [t-SNE] Computed conditional probabilities for sample 615000 / 616981
# [t-SNE] Computed conditional probabilities for sample 616000 / 616981
# [t-SNE] Computed conditional probabilities for sample 616981 / 616981
# [t-SNE] Mean sigma: 0.000000
# [t-SNE] Computed conditional probabilities in 21.266s
# [t-SNE] Iteration 50: error = 133.1906281, gradient norm = 0.0068851 (50 iterations in 1510.712s)
# [t-SNE] Iteration 100: error = 114.2020111, gradient norm = 0.0086822 (50 iterations in 110.211s)
# [t-SNE] Iteration 150: error = 107.9687271, gradient norm = 0.0123386 (50 iterations in 83.949s)
# [t-SNE] Iteration 200: error = 103.9637680, gradient norm = 0.0072104 (50 iterations in 90.216s)
# [t-SNE] Iteration 250: error = 102.0631561, gradient norm = 0.0042968 (50 iterations in 77.537s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 102.063156
# [t-SNE] Iteration 300: error = 5.2326455, gradient norm = 0.0038689 (50 iterations in 74.383s)
# [t-SNE] Iteration 350: error = 4.3339748, gradient norm = 0.0020443 (50 iterations in 73.007s)
# [t-SNE] Iteration 400: error = 3.8039410, gradient norm = 0.0021416 (50 iterations in 73.382s)
# [t-SNE] Iteration 450: error = 3.4275157, gradient norm = 0.0021826 (50 iterations in 73.304s)
# [t-SNE] Iteration 500: error = 3.0037403, gradient norm = 0.0019543 (50 iterations in 70.051s)
# [t-SNE] Iteration 550: error = 2.8074076, gradient norm = 0.0017947 (50 iterations in 70.500s)
# [t-SNE] Iteration 600: error = 2.6147900, gradient norm = 0.0016567 (50 iterations in 70.573s)
# [t-SNE] Iteration 650: error = 2.4798591, gradient norm = 0.0015465 (50 iterations in 70.562s)
# [t-SNE] Iteration 700: error = 2.3761287, gradient norm = 0.0014589 (50 iterations in 71.202s)
# [t-SNE] Iteration 750: error = 2.2588372, gradient norm = 0.0013674 (50 iterations in 71.308s)
# [t-SNE] Iteration 800: error = 2.1844749, gradient norm = 0.0012868 (50 iterations in 76.925s)
# [t-SNE] Iteration 850: error = 2.0971937, gradient norm = 0.0012272 (50 iterations in 73.904s)
# [t-SNE] Iteration 900: error = 2.0369723, gradient norm = 0.0011738 (50 iterations in 71.812s)
# [t-SNE] Iteration 950: error = 1.9555192, gradient norm = 0.0010631 (50 iterations in 72.036s)
# [t-SNE] Iteration 1000: error = 1.9091719, gradient norm = 0.0009942 (50 iterations in 71.908s)
# [t-SNE] KL divergence after 1000 iterations: 1.909172

# %%
import joblib
joblib.dump(tsne, "./tsne.pkl")
# Out:
# ['./tsne.pkl']

# %%
X_test_tsne = tsne.

# %%
# # plt.scatter(X_tsne[:,0], X_tsne[:,1], c='blue', alpha=0.1)
plt.scatter(X_tsne[train_dos_idx,0], X_tsne[train_dos_idx,1], alpha=0.1, c='green')
plt.scatter(X_tsne[train_ps_idx,0], X_tsne[train_ps_idx,1], alpha=0.1, c='red')
# # plt.scatter(X_tsne[failed_idx,0], X_tsne[failed_idx,1], c='red')

# %%
# Out:
# Index([ 36196,  36197,  36198,  36200,  36201,  36202,  36203,  36204,  36205,
#         36208,
#        ...
#         96259,  96260,  96265,  96266,  96267,  96268,  96383,  96384,  96395,
#        129835],
#       dtype='int64', length=31808)

# %%
plt.scatter(X_tsne[portscan_idx,0], X_tsne[portscan_idx,1], c='green')
